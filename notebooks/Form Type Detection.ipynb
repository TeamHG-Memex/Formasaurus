# %%
import sys
sys.path.insert(0, '..')

from formasaurus import formtype_features as features
from formasaurus import evaluation
from formasaurus.storage import Storage, load_html

# %% [markdown]
# ### Available training data

# %%
storage = Storage("../formasaurus/data")
storage.check()
storage.print_form_type_counts()
# Out:
# Checking: 100%|##########################| 343/343 [00:01<00:00, 215.33 files/s]
# Status: OK
# Annotated HTML forms:
#
# 177   search                    (s)
# 133   login                     (l)
# 113   other                     (o)
# 88    registration              (r)
# 50    password/login recovery   (p)
# 37    join mailing list         (m)
# 36    contact                   (c)
#
# Total form count: 634

# %% [markdown]
# ## Load training / evaluation data
#
# We must be careful when splitting the dataset into training and evaluation parts: forms from the same domain should be in the same "bin". There could be several pages from the same domain, and these pages may have duplicate or similar forms (e.g. a search form on each page). If we put one such form in training dataset and another in evaluation dataset then the metrics will be too optimistic, and they can make us to choose wrong features/models. For example, train_test_split from scikit-learn shouldn't be used here.
#
# As an approximation, data is sorted by a domain below (it is done in storage.get_Xy function), and then it is split into 2 parts. It means that no more than 1 domain is prone to overfitting (the one we're splitting at).

# %%
TRAIN_SIZE = 500

X, y = storage.get_Xy(verbose=True, leave=True)
X_train, X_test, y_train, y_test = X[:TRAIN_SIZE], X[TRAIN_SIZE:], y[:TRAIN_SIZE], y[TRAIN_SIZE:]

print("Train size: %d, test size: %d" % (len(y_train), len(y_test)))
# Out:
# Loading: 343 files [00:01, 233.10 files/s]
# Train size: 500, test size: 134

# %% [markdown]
# ## Ideas for useful features
#
# ### Search forms
#
# * a single query field
# * a field named "q" or "s"
# * "search" in URL
# * "search" in submit button text (submit value)
# * "search" in form css class or id
# * no password field
# * method == GET?
#
# ### Login forms
#
# * username or email and password
# * 2 passwords - likely not a login form
# * "login" or "sign in" (or variations) in URL
# * "login" or "sign in" (or variations) in form css class or id
# * "login" or "sign in" in submit button text
# * "Remember me" checkbox (or any single checkbox)
# * no select elements
# * no textarea elements
# * openid?
# * method == POST
#
# ### Registration forms
#
# * 2 passwords
# * "register" / "sign up" in URL, form css class / id or submit button text
# * "agree" checkbox
# * email
# * username
# * method == POST
#
# ### Contact forms
#
# * feedback in URL/class
# * textarea
# * "Send" button
# * email
# * method == POST
#
# ### Password reset
#
# * a single email or username field
# * "password" in URL/css class/ submit button text
#
# ### Join Mailing List
#
# * a single email field
# * subscribe/join/newsletter words
# * a short form
#
# The main problem with "join mailing list" forms is to distinguish them from search forms.
#
# ## How to handle them
#
# Instead of hardcoding the features above many of them are generalized. For exmaple, instead of writing "search in URL" we extract all 5-character substrings from the URL and use "`urlsubstring<N>` in URL" as features. There are some disadvantages in this approach, but it provides a good starting point.
#
# The feature extractors are stored in formtype.features module.

# %%
from scipy import stats as st
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.grid_search import RandomizedSearchCV
from sklearn.svm import LinearSVC
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support

# %%
# %%time
# reload(features)
from formasaurus.formtype_model import _create_feature_union
# ======= define the model ========

# features should be kept in sync with formasaurus.formtype_model
# a list of 3-tuples with default features:
# (feature_name, form_transformer, vectorizer)
FEATURES = [
    (
        "bias",
        features.Bias(),
        DictVectorizer(),
    ),
    (
        "form elements",
        features.FormElements(),
        DictVectorizer()
    ),
    (
        "<input type=submit value=...>",
        features.SubmitText(),
        CountVectorizer(ngram_range=(1,2), min_df=1, binary=True)
    ),
    (
        "<a> TEXT </a>",
        features.FormLinksText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=4, binary=True,
                        stop_words={'and', 'or', 'of'})
    ),
    (
        "<label> TEXT </label>",
        features.FormLabelText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=3, binary=True,
                        stop_words="english")
    ),

    (
        "<form action=...>",
        features.FormUrl(),
        TfidfVectorizer(ngram_range=(5,6), min_df=4, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<form class=... id=...>",
        features.FormCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input class=... id=...>",
        features.FormInputCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=5, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input name=...>",
        features.FormInputNames(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input title=...>",
        features.FormInputTitle(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
]


# clf = SGDClassifier(
#     penalty='elasticnet', 
#     loss='log', 
#     alpha=0.0002,
#     fit_intercept=False, 
#     shuffle=True, 
#     random_state=0,
#     n_iter=50,
# )
clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0, tol=0.01)

# clf = LinearSVC(C=0.5, random_state=0, fit_intercept=False)
model = Pipeline([
    ('fe', _create_feature_union(FEATURES)),
    ('clf', clf),
])

evaluation.print_metrics(model, X, y, X_train, X_test, y_train, y_test, ipython=True)
# Out:
# Classification report (500 training examples, 134 testing examples):
#
#              precision    recall  f1-score   support
#
#           c       1.00      0.88      0.93         8
#           l       0.96      0.96      0.96        28
#           m       0.80      0.40      0.53        10
#           o       0.69      1.00      0.82        18
#           p       1.00      1.00      1.00        12
#           r       1.00      0.76      0.87        17
#           s       0.95      1.00      0.98        41
#
# avg / total       0.92      0.91      0.91       134
#
# Active features: 31521 out of possible 31521
#
# Confusion matrix (rows=>true values, columns=>predicted values):
#    c   l  m   o   p   r   s
# c  7   0  0   1   0   0   0
# l  0  27  0   1   0   0   0
# m  0   0  4   4   0   0   2
# o  0   0  0  18   0   0   0
# p  0   0  0   0  12   0   0
# r  0   1  1   2   0  13   0
# s  0   0  0   0   0   0  41
# Running cross validation...
# 10-fold cross-validation F1: 0.899 (±0.093)  min=0.796  max=0.951
# CPU times: user 7.05 s, sys: 70.7 ms, total: 7.12 s
# Wall time: 7.24 s

# %% [markdown]
# ## Check what classifier learned
#
# For linear classifiers like Logistic Regression or an SVM without a kernel we can check coefficient values to understand better how the decision is made.
#
# For correlated features weight will be spread across all correlated features, so just checking coefficients is not enough, but looking at them is useful anyways.

# %%
evaluation.print_informative_features(FEATURES, clf, 25)
# Out:
# c
# +3.3912:                  form elements  has <textarea>
# +1.9744:                  <a> TEXT </a>  contact
# +1.9442:                  <a> TEXT </a>  contact us
# +1.8133:                  <a> TEXT </a>  us
# +1.5362:                  <a> TEXT </a>  privacy
# +1.1287:        <form class=... id=...>  back
# +0.9973:  <input type=submit value=...>  отправить
# +0.6817:  <input type=submit value=...>  send
# +0.6654:  <input type=submit value=...>  submit
# +0.5960:  <input type=submit value=...>  küldök
# +0.5960:  <input type=submit value=...>  neki
# +0.5960:  <input type=submit value=...>  értesítőt
# +0.5960:  <input type=submit value=...>  küldök neki
# +0.5960:  <input type=submit value=...>  értesítőt küldök
# +0.5702:          <label> TEXT </label>  message
# +0.5678:          <label> TEXT </label>  address
# +0.5454:          <label> TEXT </label>  имя
# +0.5356:          <label> TEXT </label>  phone
# +0.5278:          <label> TEXT </label>  city
# +0.5172:        <form class=... id=...>  _form
# +0.5172:        <form class=... id=...>  _for
# +0.5074:              <form action=...>   #
# +0.4628:       <input class=... id=...>  _butt
# +0.4628:       <input class=... id=...>  _but
# +0.4408:        <form class=... id=...>  ntact
#    ...
# -0.3712:        <form class=... id=...>  ntal
# -0.3796:                  form elements  has <select>
# -0.3831:  <input type=submit value=...>  register
# -0.3858:        <form class=... id=...>   sub
# -0.4000:       <input class=... id=...>   subm
# -0.4123:        <form class=... id=...>   xe
# -0.4177:  <input type=submit value=...>  now
# -0.4203:               <input name=...>   mail
# -0.4203:               <input name=...>   mail
# -0.4758:          <label> TEXT </label>  login
# -0.5016:  <input type=submit value=...>  submit your
# -0.5016:  <input type=submit value=...>  rental
# -0.5016:  <input type=submit value=...>  your rental
# -0.5016:  <input type=submit value=...>  your
# -0.5115:  <input type=submit value=...>  crear
# -0.5593:  <input type=submit value=...>  registrovať
# -0.5839:                  form elements  has <input type=email>
# -0.9264:                  form elements  exactly one <input type=password>
# -0.9657:  <input type=submit value=...>  lähetä
# -1.1084:                  form elements  <form method=get
# -1.2110:                  form elements  <form method=post
# -1.3598:                  form elements  exactly two <input type=password>
# -1.5256:                  form elements  2 or 3 inputs
# -2.2724:                  form elements  exactly one <input type=text>
# -2.3194:                           bias  bias
# --------------------------------------------------------------------------------
# l
# +2.9369:                  form elements  exactly one <input type=password>
# +1.6146:  <input type=submit value=...>  login
# +1.6049:  <input type=submit value=...>  submit
# +1.4490:  <input type=submit value=...>  in
# +1.2287:  <input type=submit value=...>  sign in
# +1.2203:              <form action=...>  login
# +1.0979:              <form action=...>  openid
# +1.0979:              <form action=...>  penid
# +1.0979:              <form action=...>  openi
# +1.0824:  <input type=submit value=...>  sign
# +0.7729:              <form action=...>  login#
# +0.7729:              <form action=...>  gin#
# +0.7729:              <form action=...>  ogin#
# +0.7729:              <form action=...>  ogin#
# +0.6920:              <form action=...>  penidl
# +0.6920:              <form action=...>  dlogi
# +0.6920:              <form action=...>  idlogi
# +0.6920:              <form action=...>  dlogin
# +0.6920:              <form action=...>  enidl
# +0.6920:              <form action=...>  idlog
# +0.6920:              <form action=...>  nidlo
# +0.6920:              <form action=...>  nidlog
# +0.6920:              <form action=...>  enidlo
# +0.6638:                  <a> TEXT </a>  sign up
# +0.6229:                  form elements  has <input type=checkbox>
#    ...
# -0.4445:               <input name=...>  first
# -0.4799:                  <a> TEXT </a>  log
# -0.4993:              <form action=...>   auth
# -0.4999:               <input name=...>  email
# -0.5188:  <input type=submit value=...>  register now
# -0.5189:  <input type=submit value=...>  now
# -0.5216:                  <a> TEXT </a>  terms
# -0.5519:               <input name=...>  mail
# -0.5551:               <input name=...>  email
# -0.5564:                  form elements  <form method=get
# -0.5598:                  form elements  <form method=post
# -0.5970:               <input name=...>   q
# -0.6141:          <label> TEXT </label>  mail
# -0.7681:                  <a> TEXT </a>  com
# -0.7713:                  form elements  has <input type=radio>
# -0.9020:                  form elements  has <textarea>
# -0.9082:  <input type=submit value=...>  regisztráció
# -0.9158:  <input type=submit value=...>  зарегистрироваться
# -1.0533:  <input type=submit value=...>  register
# -1.1162:                           bias  bias
# -1.2636:                  form elements  3 or more <input type=text>
# -1.3422:                  form elements  has <input type=email>
# -1.4559:                  form elements  exactly two <input type=password>
# -1.5851:                  form elements  has <select>
# -2.5824:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# m
# +1.9539:  <input type=submit value=...>  subscribe
# +1.4466:        <form class=... id=...>  mail
# +1.4131:                  form elements  has <input type=email>
# +1.0183:              <form action=...>  subsc
# +1.0183:              <form action=...>  ubscri
# +1.0183:              <form action=...>  bscri
# +1.0183:              <form action=...>  subscr
# +1.0183:              <form action=...>  ubscr
# +0.9340:               <input name=...>  email
# +0.9025:               <input name=...>   email
# +0.9025:               <input name=...>   emai
# +0.7916:          <label> TEXT </label>  offers
# +0.7820:               <input name=...>  maili
# +0.7780:        <form class=... id=...>  lett
# +0.7780:        <form class=... id=...>  slet
# +0.7780:        <form class=... id=...>  wslet
# +0.7780:        <form class=... id=...>  lette
# +0.7780:        <form class=... id=...>  ette
# +0.7780:        <form class=... id=...>  ewsl
# +0.7780:        <form class=... id=...>  newsl
# +0.7780:        <form class=... id=...>  etter
# +0.7780:        <form class=... id=...>  slett
# +0.7780:        <form class=... id=...>  ewsle
# +0.7780:        <form class=... id=...>   news
# +0.7780:        <form class=... id=...>  wsle
#    ...
# -0.3457:       <input class=... id=...>  earch
# -0.3457:       <input class=... id=...>  searc
# -0.3520:       <input class=... id=...>   btn
# -0.3642:          <label> TEXT </label>  mail address
# -0.3657:       <input class=... id=...>  arch
# -0.3906:        <form class=... id=...>  orm
# -0.3906:        <form class=... id=...>  form
# -0.3992:  <input type=submit value=...>  search
# -0.4035:  <input type=submit value=...>  login
# -0.4981:          <label> TEXT </label>  address
# -0.6188:  <input type=submit value=...>  reset
# -0.6414:                  form elements  has <input type=radio>
# -0.6464:                  form elements  exactly two <input type=text>
# -0.7092:                  form elements  no <input type=text>
# -0.7434:               <input name=...>   q
# -0.7779:                  form elements  exactly two <input type=password>
# -0.8143:                  form elements  has <textarea>
# -0.9470:                  form elements  has <select>
# -0.9631:                  form elements  3 or more <input type=text>
# -1.0021:                  form elements  <form method=post
# -1.0439:          <label> TEXT </label>  mail
# -1.1643:          <label> TEXT </label>  email
# -1.5230:                  form elements  <form method=get
# -1.5965:                  form elements  exactly one <input type=password>
# -2.5250:                           bias  bias
# --------------------------------------------------------------------------------
# o
# +2.1561:        <form class=... id=...>   xe
# +1.8572:                  form elements  no <input type=password>
# +1.4072:                  form elements  no <input type=text>
# +1.3784:               <input name=...>   qty
# +1.1422:        <form class=... id=...>   form
# +1.0792:  <input type=submit value=...>  lähetä
# +0.9942:  <input type=submit value=...>  keresés mentése
# +0.9942:  <input type=submit value=...>  mentése
# +0.9823:              <input title=...>   to
# +0.9106:        <form class=... id=...>   for
# +0.9098:              <form action=...>  ers#
# +0.8816:                  <a> TEXT </a>  new
# +0.8670:        <form class=... id=...>  jump
# +0.8540:        <form class=... id=...>  dal_
# +0.8540:        <form class=... id=...>  odal
# +0.8540:        <form class=... id=...>  odal_
# +0.8540:        <form class=... id=...>  modal
# +0.8540:        <form class=... id=...>  moda
# +0.8375:        <form class=... id=...>  orm-s
# +0.8375:        <form class=... id=...>  rm-s
# +0.8252:               <input name=...>  temail
# +0.8252:               <input name=...>  temai
# +0.7962:  <input type=submit value=...>  publikál
# +0.7939:                  <a> TEXT </a>  10
# +0.7464:               <input name=...>  ntemai
#    ...
# -0.8250:              <form action=...>   sear
# -0.8257:               <input name=...>   sear
# -0.8257:               <input name=...>   searc
# -0.8261:  <input type=submit value=...>  go
# -0.8463:  <input type=submit value=...>  reset
# -0.8688:                  form elements  has <textarea>
# -0.8723:       <input class=... id=...>  email
# -0.8723:       <input class=... id=...>  emai
# -0.8933:                  <a> TEXT </a>  privacy
# -0.9038:       <input class=... id=...>  mail
# -0.9429:                           bias  bias
# -0.9440:               <input name=...>   emai
# -0.9440:               <input name=...>   email
# -1.0415:               <input name=...>  email
# -1.0466:          <label> TEXT </label>  search
# -1.0718:        <form class=... id=...>  back
# -1.0789:               <input name=...>  mail
# -1.1487:                  <a> TEXT </a>  contact
# -1.1950:               <input name=...>  email
# -1.2155:                  form elements  exactly two <input type=password>
# -1.2232:                  form elements  exactly one <input type=text>
# -1.3231:  <input type=submit value=...>  search
# -1.5097:                  form elements  exactly one <input type=password>
# -1.5174:                  form elements  has <input type=email>
# -2.3525:               <input name=...>   q
# --------------------------------------------------------------------------------
# p
# +1.6733:  <input type=submit value=...>  reset
# +1.3191:  <input type=submit value=...>  priminti
# +1.1955:  <input type=submit value=...>  password
# +1.1638:          <label> TEXT </label>  email
# +1.1590:  <input type=submit value=...>  odošli
# +1.0230:               <input name=...>   email
# +1.0230:               <input name=...>   emai
# +1.0125:  <input type=submit value=...>  enviar
# +0.9926:  <input type=submit value=...>  lähetä
# +0.9906:        <form class=... id=...>  forgo
# +0.9906:        <form class=... id=...>  rgot
# +0.9906:        <form class=... id=...>  orgo
# +0.9906:        <form class=... id=...>  orgot
# +0.9906:        <form class=... id=...>  forg
# +0.9584:              <form action=...>  asswor
# +0.9584:              <form action=...>  passwo
# +0.9584:              <form action=...>  passw
# +0.9584:              <form action=...>  asswo
# +0.9584:              <form action=...>  sswor
# +0.9340:               <input name=...>  email
# +0.9049:                  form elements  2 or 3 inputs
# +0.9046:          <label> TEXT </label>  mail
# +0.8949:  <input type=submit value=...>  weiter
# +0.8934:                  form elements  has <input type=email>
# +0.8805:        <form class=... id=...>   forg
#    ...
# -0.4253:       <input class=... id=...>  earch
# -0.4253:       <input class=... id=...>  searc
# -0.4529:       <input class=... id=...>  arch
# -0.4668:       <input class=... id=...>  sear
# -0.4675:              <form action=...>  subscr
# -0.4675:              <form action=...>  ubscr
# -0.4675:              <form action=...>  ubscri
# -0.4675:              <form action=...>  bscri
# -0.4675:              <form action=...>  subsc
# -0.5126:  <input type=submit value=...>  register
# -0.5226:        <form class=... id=...>   form
# -0.5399:  <input type=submit value=...>  search
# -0.7327:                  form elements  has <input type=radio>
# -0.7531:                  form elements  <form method=post
# -0.8560:                  form elements  exactly two <input type=password>
# -0.8847:               <input name=...>   q
# -1.0086:                  form elements  no <input type=text>
# -1.1556:  <input type=submit value=...>  subscribe
# -1.2274:                  form elements  has <input type=checkbox>
# -1.2366:                  form elements  has <textarea>
# -1.3633:                  form elements  3 or more <input type=text>
# -1.6501:                  form elements  has <select>
# -1.9310:                  form elements  <form method=get
# -2.2165:                  form elements  exactly one <input type=password>
# -2.6840:                           bias  bias
# --------------------------------------------------------------------------------
# r
# +2.5169:                  form elements  exactly two <input type=password>
# +1.5069:  <input type=submit value=...>  register
# +1.4121:                  form elements  3 or more <input type=text>
# +1.2502:  <input type=submit value=...>  create
# +1.1606:                  form elements  has <input type=email>
# +1.1344:  <input type=submit value=...>  registrovať
# +1.1068:  <input type=submit value=...>  regisztráció
# +0.9885:              <form action=...>   auth
# +0.9227:                  <a> TEXT </a>  com
# +0.9196:  <input type=submit value=...>  зарегистрироваться
# +0.8891:  <input type=submit value=...>  account
# +0.8625:                  form elements  has <input type=radio>
# +0.8156:               <input name=...>  mail
# +0.7983:              <form action=...>  regis
# +0.7821:              <form action=...>  regist
# +0.7821:              <form action=...>  egist
# +0.7754:              <form action=...>  creat
# +0.7754:              <form action=...>  create
# +0.7754:              <form action=...>  reate
# +0.7670:              <form action=...>  giste
# +0.7670:              <form action=...>  gister
# +0.7670:              <form action=...>  ister
# +0.7670:              <form action=...>  egiste
# +0.7471:  <input type=submit value=...>  now
# +0.7145:              <form action=...>  ster#
#    ...
# -0.3659:  <input type=submit value=...>  отправить
# -0.3683:        <form class=... id=...>  form
# -0.3870:                  form elements  has <input type=checkbox>
# -0.3888:              <form action=...>   logi
# -0.3888:              <form action=...>   login
# -0.3901:                  <a> TEXT </a>  password
# -0.4185:  <input type=submit value=...>  belépés
# -0.4311:                  <a> TEXT </a>  10
# -0.4417:              <form action=...>  gin#
# -0.4417:              <form action=...>  ogin#
# -0.4417:              <form action=...>  login#
# -0.4417:              <form action=...>  ogin#
# -0.4560:                  <a> TEXT </a>  forgot
# -0.6066:              <form action=...>  login
# -0.6147:          <label> TEXT </label>  remember
# -0.6841:  <input type=submit value=...>  in
# -0.8144:                  form elements  exactly one <input type=password>
# -0.8997:                           bias  bias
# -0.9315:                  form elements  has <textarea>
# -1.1500:                  form elements  <form method=get
# -1.1939:  <input type=submit value=...>  login
# -1.2636:                  form elements  exactly one <input type=text>
# -1.4544:                  form elements  no <input type=text>
# -1.8601:                  form elements  2 or 3 inputs
# -2.6987:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# s
# +3.0824:               <input name=...>   q
# +2.0472:  <input type=submit value=...>  search
# +1.2895:  <input type=submit value=...>  go
# +1.1743:          <label> TEXT </label>  search
# +1.1358:               <input name=...>   sear
# +1.1358:               <input name=...>   searc
# +1.1336:              <form action=...>   searc
# +1.1336:              <form action=...>   sear
# +1.1168:       <input class=... id=...>  earch
# +1.1168:       <input class=... id=...>  earc
# +1.1168:       <input class=... id=...>  searc
# +1.1076:               <input name=...>   s
# +1.0961:                  form elements  exactly one <input type=text>
# +1.0950:        <form class=... id=...>  arch
# +1.0950:        <form class=... id=...>  earch
# +1.0950:        <form class=... id=...>  searc
# +1.0950:        <form class=... id=...>  sear
# +1.0950:        <form class=... id=...>  earc
# +1.0884:       <input class=... id=...>  sear
# +1.0840:       <input class=... id=...>  arch
# +0.9829:              <form action=...>  earch
# +0.9829:              <form action=...>  search
# +0.9829:              <form action=...>  searc
# +0.9758:               <input name=...>  search
# +0.9758:               <input name=...>  earch
#    ...
# -0.5441:               <input name=...>  name
# -0.5622:        <form class=... id=...>  rform
# -0.5622:        <form class=... id=...>  rfor
# -0.5915:                  form elements  exactly two <input type=text>
# -0.5948:                  <a> TEXT </a>  contact
# -0.6012:                  <a> TEXT </a>  contact us
# -0.6038:                  <a> TEXT </a>  us
# -0.6583:                  <a> TEXT </a>  privacy
# -0.7170:        <form class=... id=...>  form
# -0.7170:        <form class=... id=...>  orm
# -0.7445:        <form class=... id=...>  jump
# -0.7741:                  form elements  3 or more <input type=text>
# -0.7805:               <input name=...>  mail
# -0.7860:               <input name=...>  email
# -0.8305:                  form elements  has <textarea>
# -0.8308:  <input type=submit value=...>  submit
# -0.8734:               <input name=...>   email
# -0.8734:               <input name=...>   emai
# -0.8877:               <input name=...>   qty
# -0.9170:               <input name=...>  email
# -1.3666:                  form elements  no <input type=text>
# -1.4155:        <form class=... id=...>   xe
# -1.5953:                  form elements  exactly one <input type=password>
# -1.6363:                           bias  bias
# -1.8867:                  form elements  <form method=post
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Compare results with "loginform" library
#
# It is not possible to compare the results with "loginform" library directly because loginform
#
# * always tries to return a login form even if the score is low;
# * only detects login forms;
# * in case of several forms returns a single form with the best score instead of deciding for each form whether to return it or not.
#
# So we used two approaches:
#
# 1. Use `loginform._form_score` with different thresholds; assume that if score is greater than or equal to a threshold `loginform` detected a login form.
# 2. Train the same model, but using features from loginform library (weights will be learned instead of being hardcoded as 'score' increments/decrements).

# %% [markdown]
# ### 1. loginform scores + thresholds
#
# * **score >= -100** means "simply treat all forms as login forms".
#
# * **score >= 0** all (or most) login forms are captured, but there are many false positives.
#   It is only slightly better than treating all forms as login forms.
#
# * **score >= 10** F1 score is the best among all thresholds,
#   but the quality is significantly worse than F1 of ML-based models.
#
# * **score >= 20** ~90% of detected login forms are correct, but most
#   login forms are not detected. Also, ~90% number is still lower than what ML-based models give us.

# %%
# %%time 
import loginform


def labels_to_binary(y):
    """ Convert labels to 2-classes: login forms and non-login forms """
    return [tp == 'l' for tp in y]

    
def predict_loginform(X, threshold):
    """
    Return if forms are login or not using loginform
    library scores and a threshold.
    """
    return [
        (loginform._form_score(form) >= threshold)
        for form in X
    ]


def print_threshold_metrics(X_test, y_test, threshold):
    y_test = labels_to_binary(y_test)
    y_pred = predict_loginform(X_test, threshold)

    precision, recall, f1, support = precision_recall_fscore_support(y_test, y_pred, pos_label=True)
    print(
        "score >= %4d:    precision = %0.3f    recall = %0.3f    F1 = %0.3f" % (
        threshold, precision[1], recall[1], f1[1]
    ))


for threshold in [-100, -10, 0, 10, 20, 30]:
    print_threshold_metrics(X_test, y_test, threshold)
# Out:
# score >= -100:    precision = 0.209    recall = 1.000    F1 = 0.346
# score >=  -10:    precision = 0.241    recall = 0.964    F1 = 0.386
# score >=    0:    precision = 0.435    recall = 0.964    F1 = 0.600
# score >=   10:    precision = 0.733    recall = 0.786    F1 = 0.759
# score >=   20:    precision = 0.875    recall = 0.250    F1 = 0.389
# score >=   30:    precision = 0.000    recall = 0.000    F1 = 0.000
# CPU times: user 196 ms, sys: 1.24 ms, total: 197 ms
# Wall time: 200 ms
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 2. Use loginform features, but autodetect scores
#
# The following ML-based model is trained using original loginform features (conditions used to increase or decrease the score). Roughly speaking, it uses the same information as loginform library, but instead of hardcoding `score += 10` and `score -= 10` the numbers are adjusted based on training data.
#
# Note that the login form detection quality is significantly better than the quality of threshold-based model; it is only slightly worse than the quality of a "full" forms detection model. This means original loginform features are quite good at detecting login forms. But for other form types these features are not enough: other scores are bad.

# %%
# %%time

LOGINFORM_FEATURES = [
    ('bias', features.Bias(), DictVectorizer()),
    ('loginform', features.OldLoginformFeatures(), DictVectorizer())
]
# loginform_clf = LinearSVC(C=0.5, fit_intercept=False)
loginform_clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0)

model = make_pipeline(
    _create_feature_union(LOGINFORM_FEATURES), 
    loginform_clf,
)

evaluation.print_metrics(model, X, y, X_train, X_test, y_train, y_test, ipython=True)
evaluation.print_informative_features(LOGINFORM_FEATURES, loginform_clf, 25)
# Out:
# Classification report (500 training examples, 134 testing examples):
#
#              precision    recall  f1-score   support
#
#           c       0.88      0.88      0.88         8
#           l       0.93      0.96      0.95        28
#           m       0.00      0.00      0.00        10
#           o       0.64      1.00      0.78        18
#           p       0.00      0.00      0.00        12
#           r       0.86      0.71      0.77        17
#           s       0.67      0.90      0.77        41
#
# avg / total       0.65      0.75      0.69       134
#
# Active features: 56 out of possible 56
#
# Confusion matrix (rows=>true values, columns=>predicted values):
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#    c   l  m   o  p   r   s
# c  7   0  0   1  0   0   0
# l  0  27  0   1  0   0   0
# m  0   0  0   0  0   0  10
# o  0   0  0  18  0   0   0
# p  0   0  0   5  0   0   7
# r  1   2  0   1  0  12   1
# s  0   0  0   2  0   2  37
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Running cross validation...
# 10-fold cross-validation F1: 0.647 (±0.105)  min=0.573  max=0.728
# c
# +3.8501:                      loginform  typecount_text_gt1
# +2.5960:                      loginform  typecount_password_0
# +0.8810:                      loginform  typecount_text_0
# -0.5189:                      loginform  typecount_radio_gt0
# -1.2757:                      loginform  typecount_checkbox_gt1
# -1.4178:                      loginform  typecount_password_eq1
# -3.0174:                      loginform  2_or_3_inputs
# -6.5263:                           bias  bias
# --------------------------------------------------------------------------------
# l
# +4.6357:                      loginform  typecount_password_eq1
# +0.6044:                      loginform  typecount_text_0
# +0.0533:                      loginform  2_or_3_inputs
# -1.6830:                      loginform  typecount_password_0
# -1.7110:                      loginform  typecount_text_gt1
# -2.0244:                           bias  bias
# -2.0933:                      loginform  typecount_radio_gt0
# -2.6036:                      loginform  typecount_checkbox_gt1
# --------------------------------------------------------------------------------
# m
# +1.2178:                      loginform  typecount_password_0
# +0.9617:                      loginform  typecount_checkbox_gt1
# +0.5422:                      loginform  2_or_3_inputs
# +0.4155:                      loginform  typecount_text_0
# -0.4592:                      loginform  typecount_text_gt1
# -1.8464:                      loginform  typecount_radio_gt0
# -1.9165:                      loginform  typecount_password_eq1
# -3.9453:                           bias  bias
# --------------------------------------------------------------------------------
# o
# +2.5701:                      loginform  typecount_password_0
# +1.8790:                      loginform  typecount_text_0
# +0.4269:                      loginform  typecount_text_gt1
# +0.2711:                      loginform  typecount_radio_gt0
# -0.0971:                      loginform  typecount_checkbox_gt1
# -0.2108:                      loginform  2_or_3_inputs
# -1.8807:                      loginform  typecount_password_eq1
# -4.1727:                           bias  bias
# --------------------------------------------------------------------------------
# p
# +1.1818:                      loginform  typecount_password_0
# +0.7858:                      loginform  2_or_3_inputs
# -0.9267:                      loginform  typecount_text_0
# -1.3233:                      loginform  typecount_checkbox_gt1
# -1.3646:                      loginform  typecount_text_gt1
# -1.5401:                      loginform  typecount_radio_gt0
# -2.3201:                      loginform  typecount_password_eq1
# -3.2083:                           bias  bias
# --------------------------------------------------------------------------------
# r
# +2.2855:                      loginform  typecount_text_gt1
# +1.4710:                      loginform  typecount_checkbox_gt1
# +1.1164:                           bias  bias
# +0.9953:                      loginform  typecount_radio_gt0
# +0.9063:                      loginform  typecount_text_0
# -1.0896:                      loginform  2_or_3_inputs
# -3.7490:                      loginform  typecount_password_eq1
# -5.3577:                      loginform  typecount_password_0
# --------------------------------------------------------------------------------
# s
# +2.9714:                      loginform  typecount_password_0
# +0.5333:                      loginform  typecount_radio_gt0
# +0.0396:                      loginform  2_or_3_inputs
# -0.1989:                      loginform  typecount_checkbox_gt1
# -1.9890:                      loginform  typecount_text_0
# -2.5252:                      loginform  typecount_password_eq1
# -2.6442:                           bias  bias
# -2.8061:                      loginform  typecount_text_gt1
# --------------------------------------------------------------------------------
# CPU times: user 2.23 s, sys: 9.49 ms, total: 2.24 s
# Wall time: 2.29 s
