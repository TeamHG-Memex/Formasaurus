# %%
import sys
sys.path.insert(0, '..')

from formasaurus import formtype_features as features
from formasaurus import formtype_model
from formasaurus.storage import Storage, load_html

# %% [markdown]
# ### Available training data

# %%
storage = Storage("../formasaurus/data")
storage.check()
storage.print_form_type_counts(simplify=True)
# Out:
# Checking: 100%|##########################| 832/832 [00:04<00:00, 162.55 files/s]
# Status: OK
# Annotated HTML forms (simplified classes):
#
# 364   search                    (s)
# 221   login                     (l)
# 153   registration              (r)
# 122   other                     (o)
# 120   contact/comment           (c)
# 107   join mailing list         (m)
# 95    password/login recovery   (p)
# 62    order/add to cart         (b)
#
# Total form count: 1244

# %% [markdown]
# ## Load training / evaluation data

# %%
annotations = list(storage.iter_annotations(
    simplify_form_types=True,
    simplify_field_types=True,
    verbose=True,
    leave=True,        
))
X, y = formtype_model.get_Xy(annotations, full_type_names=True)
# Out:
# Loading: 832 files [00:03, 259.92 files/s]

# %% [markdown]
# ## Ideas for useful features
#
# ### Search forms
#
# * a single query field
# * a field named "q" or "s"
# * "search" in URL
# * "search" in submit button text (submit value)
# * "search" in form css class or id
# * no password field
# * method == GET?
#
# ### Login forms
#
# * username or email and password
# * 2 passwords - likely not a login form
# * "login" or "sign in" (or variations) in URL
# * "login" or "sign in" (or variations) in form css class or id
# * "login" or "sign in" in submit button text
# * "Remember me" checkbox (or any single checkbox)
# * no select elements
# * no textarea elements
# * openid?
# * method == POST
#
# ### Registration forms
#
# * 2 passwords
# * "register" / "sign up" in URL, form css class / id or submit button text
# * "agree" checkbox
# * email
# * username
# * method == POST
#
# ### Contact forms
#
# * feedback in URL/class
# * textarea
# * "Send" button
# * email
# * method == POST
#
# ### Password reset
#
# * a single email or username field
# * "password" in URL/css class/ submit button text
#
# ### Join Mailing List
#
# * a single email field
# * subscribe/join/newsletter words
# * a short form
#
# The main problem with "join mailing list" forms is to distinguish them from search forms.
#
# ## How to handle them
#
# Instead of hardcoding the features above many of them are generalized. For exmaple, instead of writing "search in URL" we extract all 5-character substrings from the URL and use "`urlsubstring<N>` in URL" as features. There are some disadvantages in this approach, but it provides a good starting point.
#
# The feature extractors are stored in formtype.features module.

# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, precision_recall_fscore_support

# %%
# %%time
# reload(features)
from formasaurus.formtype_model import _create_feature_union
# ======= define the model ========

# features should be kept in sync with formasaurus.formtype_features
# a list of 3-tuples with default features:
# (feature_name, form_transformer, vectorizer)
FEATURES = [
    (
        "bias",
        features.Bias(),
        DictVectorizer(),
    ),
    (
        "form elements",
        features.FormElements(),
        DictVectorizer()
    ),
    (
        "<input type=submit value=...>",
        features.SubmitText(),
        CountVectorizer(ngram_range=(1,2), min_df=1, binary=True)
    ),
    (
        "<a> TEXT </a>",
        features.FormLinksText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=4, binary=True,
                        stop_words={'and', 'or', 'of'})
    ),
    (
        "<label> TEXT </label>",
        features.FormLabelText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=3, binary=True,
                        stop_words="english")
    ),

    (
        "<form action=...>",
        features.FormUrl(),
        TfidfVectorizer(ngram_range=(5,6), min_df=4, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<form class=... id=...>",
        features.FormCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input class=... id=...>",
        features.FormInputCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=5, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input name=...>",
        features.FormInputNames(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input title=...>",
        features.FormInputTitle(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
]


# clf = SGDClassifier(
#     penalty='elasticnet', 
#     loss='log', 
#     alpha=0.0002,
#     fit_intercept=False, 
#     shuffle=True, 
#     random_state=0,
#     n_iter=50,
# )
clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0, tol=0.01)

# clf = LinearSVC(C=0.5, random_state=0, fit_intercept=False)
model = Pipeline([
    ('fe', _create_feature_union(FEATURES)),
    ('clf', clf),
])

formtype_model.print_classification_report(annotations, n_folds=10, model=model)
# Out:
#                          precision    recall  f1-score   support
#
#                  search       0.90      0.96      0.93       364
#                   login       0.96      0.96      0.96       221
#            registration       0.96      0.84      0.90       153
# password/login recovery       0.89      0.87      0.88        95
#         contact/comment       0.86      0.95      0.90       120
#       join mailing list       0.92      0.86      0.89       107
#       order/add to cart       0.95      0.66      0.78        62
#                   other       0.65      0.70      0.67       122
#
#             avg / total       0.89      0.89      0.89      1244
#
# 88.8% forms are classified correctly.
# CPU times: user 12.7 s, sys: 70 ms, total: 12.7 s
# Wall time: 12.9 s

# %% [markdown]
# ## Check what classifier learned
#
# For linear classifiers like Logistic Regression or an SVM without a kernel we can check coefficient values to understand better how the decision is made.
#
# For correlated features (notably, n-grams) weight will be spread across all correlated features, so just checking coefficients is not enough, but looking at them is useful anyways.

# %%
def get_informative_features(vectorizers, clf, class_labels, N):
    """
    Return text with features with the highest absolute coefficient
    values, per class.
    """
    feature_names = []
    for vec_name, vec in vectorizers:
        feature_names.extend(
            "%30s  %s" % (vec_name, name) for name in vec.get_feature_names()
        )
    features_by_class = []
    for i, class_label in enumerate(class_labels):
        topN = np.argsort(clf.coef_[i])[-N:]
        bottomN = np.argsort(clf.coef_[i])[:N]
        res = []

        for j in reversed(topN):
            coef = clf.coef_[i][j]
            if coef > 0:
                res.append("+%0.4f: %s" % (coef, feature_names[j]))

        if (len(topN) >= N) or (len(bottomN) >= N):
            res.append("   ...")

        for j in reversed(bottomN):
            coef = clf.coef_[i][j]
            if coef < 0:
                res.append("%0.4f: %s" % (coef, feature_names[j]))
        features_by_class.append((class_label, '\n'.join(res)))
    return features_by_class


def print_informative_features(features, clf, top, classes=None, class_map=None):
    vectorizers = [(name, vec) for (name, fe, vec) in features]
    feat_info = get_informative_features(vectorizers, clf, clf.classes_, top)
    for cls, report in feat_info:
        if classes is not None and cls not in classes:
            continue
        if class_map is not None:
            print(class_map[cls])
        else:
            print(cls)
        print(report)
        print("-"*80)

# %%
model.fit(X, y)
print_informative_features(FEATURES, clf, 25)
# Out:
# contact/comment
# +5.7038:                  form elements  has <textarea>
# +2.4165:          <label> TEXT </label>  question
# +1.6252:              <form action=...>   kont
# +1.5018:                  <a> TEXT </a>  agent
# +1.4977:                  <a> TEXT </a>  affiliate
# +1.4516:                  <a> TEXT </a>  mobile
# +1.4413:                  <a> TEXT </a>  forums
# +1.4255:                  <a> TEXT </a>  privacy statement
# +1.3809:                  <a> TEXT </a>  statement
# +1.2500:                  <a> TEXT </a>  contact
# +1.2029:          <label> TEXT </label>  message
# +1.1769:  <input type=submit value=...>  send
# +1.1669:                  <a> TEXT </a>  contact us
# +1.0759:                  <a> TEXT </a>  us
# +0.8678:                  <a> TEXT </a>  privacy
# +0.8337:        <form class=... id=...>  ques
# +0.8337:        <form class=... id=...>  uest
# +0.8337:        <form class=... id=...>  quest
# +0.7952:                  <a> TEXT </a>  http
# +0.7952:                  <a> TEXT </a>  http www
# +0.7929:          <label> TEXT </label>  comments
# +0.7821:        <form class=... id=...>  new_
# +0.7783:          <label> TEXT </label>  email message
# +0.7515:        <form class=... id=...>  t-for
# +0.7230:              <form action=...>   send
#    ...
# -0.6004:        <form class=... id=...>   web
# -0.6034:  <input type=submit value=...>  crear
# -0.6097:        <form class=... id=...>   ord
# -0.6218:  <input type=submit value=...>  now
# -0.6270:              <form action=...>  .aspx
# -0.6448:        <form class=... id=...>  site
# -0.6517:  <input type=submit value=...>  next
# -0.6590:        <form class=... id=...>  ine
# -0.6947:               <input name=...>   mail
# -0.7087:          <label> TEXT </label>  login
# -0.7183:               <input name=...>   mail
# -0.7208:              <form action=...>  entry
# -0.7576:              <form action=...>  tiona
# -0.8367:  <input type=submit value=...>  registrovať
# -0.9819:  <input type=submit value=...>  корзину отправить
# -0.9819:  <input type=submit value=...>  корзину
# -0.9992:                  form elements  has <input type=checkbox>
# -1.0937:                  form elements  exactly one <input type=password>
# -1.1305:  <input type=submit value=...>  lähetä
# -1.1848:        <form class=... id=...>   add
# -1.3443:                  form elements  <form method=post
# -1.5250:                  form elements  <form method=get
# -1.7970:                  form elements  exactly one <input type=text>
# -2.4422:                  form elements  exactly two <input type=password>
# -2.8693:                           bias  bias
# --------------------------------------------------------------------------------
# join mailing list
# +1.6450:               <input name=...>   go
# +1.5434:  <input type=submit value=...>  subscribe
# +1.4718:  <input type=submit value=...>  подписаться
# +1.4146:        <form class=... id=...>  mail
# +1.4105:               <input name=...>   email
# +1.4105:               <input name=...>   emai
# +1.2600:               <input name=...>  news
# +1.1598:        <form class=... id=...>  news
# +1.1292:  <input type=submit value=...>  cadastrar
# +1.1240:               <input name=...>   zip
# +1.1068:               <input name=...>  email
# +1.0610:                  <a> TEXT </a>  list
# +1.0257:               <input name=...>   em
# +1.0009:  <input type=submit value=...>  up
# +0.9915:        <form class=... id=...>  subs
# +0.9915:        <form class=... id=...>  bscri
# +0.9915:        <form class=... id=...>  ubscr
# +0.9915:        <form class=... id=...>  subsc
# +0.9915:        <form class=... id=...>  bscr
# +0.9915:        <form class=... id=...>  ubsc
# +0.9784:        <form class=... id=...>  scri
# +0.9654:                  form elements  has <input type=email>
# +0.9158:        <form class=... id=...>  newsl
# +0.9158:        <form class=... id=...>  lette
# +0.9158:        <form class=... id=...>  lett
#    ...
# -0.5799:        <form class=... id=...>  arch
# -0.5799:        <form class=... id=...>  earc
# -0.5799:        <form class=... id=...>  earch
# -0.5799:        <form class=... id=...>  sear
# -0.5799:        <form class=... id=...>  searc
# -0.5913:              <form action=...>   auth
# -0.6019:                  form elements  exactly two <input type=text>
# -0.6556:               <input name=...>   s
# -0.6672:          <label> TEXT </label>  adresse
# -0.6714:               <input name=...>   qty
# -0.7356:  <input type=submit value=...>  reset
# -0.7450:  <input type=submit value=...>  password
# -0.7454:  <input type=submit value=...>  send
# -0.8024:          <label> TEXT </label>  password
# -0.9132:          <label> TEXT </label>  mail
# -1.0151:                  form elements  <form method=post
# -1.0372:               <input name=...>   q
# -1.2096:                  form elements  no <input type=text>
# -1.3057:                  form elements  has <select>
# -1.4407:          <label> TEXT </label>  email
# -1.6303:                  form elements  exactly two <input type=password>
# -1.6498:                  form elements  <form method=get
# -1.8700:                  form elements  exactly one <input type=password>
# -2.2611:                  form elements  has <textarea>
# -2.6649:                           bias  bias
# --------------------------------------------------------------------------------
# login
# +3.4676:                  form elements  exactly one <input type=password>
# +3.0437:              <form action=...>  login
# +1.8578:  <input type=submit value=...>  submit
# +1.6853:  <input type=submit value=...>  login
# +1.4220:  <input type=submit value=...>  in
# +1.1362:  <input type=submit value=...>  sign in
# +1.0704:              <form action=...>  openid
# +1.0704:              <form action=...>  penid
# +1.0704:              <form action=...>  openi
# +0.9925:  <input type=submit value=...>  войти
# +0.8803:  <input type=submit value=...>  sign
# +0.8713:                  <a> TEXT </a>  password
# +0.8186:  <input type=submit value=...>  войти войти
# +0.8152:                  form elements  no <input type=text>
# +0.7150:              <form action=...>  login#
# +0.7150:              <form action=...>  ogin#
# +0.7150:              <form action=...>  gin#
# +0.7150:              <form action=...>  ogin#
# +0.7132:        <form class=... id=...>   cer
# +0.7073:          <label> TEXT </label>  remember
# +0.7030:              <form action=...>  nidlog
# +0.7030:              <form action=...>  idlogi
# +0.7030:              <form action=...>  nidlo
# +0.7030:              <form action=...>  idlog
# +0.7030:              <form action=...>  enidl
#    ...
# -0.4956:               <input name=...>   emai
# -0.5225:          <label> TEXT </label>  mail
# -0.5261:               <input name=...>  email
# -0.5304:  <input type=submit value=...>  register now
# -0.5339:  <input type=submit value=...>  now
# -0.5756:  <input type=submit value=...>  create account
# -0.5971:                  <a> TEXT </a>  terms service
# -0.6065:               <input name=...>   q
# -0.6197:                  <a> TEXT </a>  service
# -0.6198:                  <a> TEXT </a>  terms
# -0.7410:                  <a> TEXT </a>  com
# -0.7453:  <input type=submit value=...>  account
# -0.8192:  <input type=submit value=...>  create
# -0.8264:                  form elements  <form method=get
# -0.9210:                  form elements  has <textarea>
# -0.9691:                  form elements  has <input type=radio>
# -0.9838:  <input type=submit value=...>  regisztráció
# -0.9911:  <input type=submit value=...>  зарегистрироваться
# -1.0778:  <input type=submit value=...>  register
# -1.2453:                           bias  bias
# -1.5587:                  form elements  3 or more <input type=text>
# -1.6171:                  form elements  exactly two <input type=password>
# -2.0253:                  form elements  has <input type=email>
# -2.1271:                  form elements  has <select>
# -3.0937:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# order/add to cart
# +3.2276:               <input name=...>   qty
# +2.2659:              <form action=...>   cart
# +1.9486:  <input type=submit value=...>  заказ
# +1.6611:                  <a> TEXT </a>  email
# +1.6561:               <input name=...>  list
# +1.6211:              <form action=...>   prod
# +1.3930:               <input name=...>  quant
# +1.3703:               <input name=...>  oncode
# +1.3703:               <input name=...>  oncod
# +1.2964:               <input name=...>  ncode
# +1.2964:               <input name=...>  ncode
# +1.2338:  <input type=submit value=...>  оплатить заказ
# +1.2338:  <input type=submit value=...>  оплатить
# +1.1704:          <label> TEXT </label>  quantity
# +1.1315:                  <a> TEXT </a>  to
# +1.1281:                  form elements  has <select>
# +1.1247:  <input type=submit value=...>  acquista
# +1.1220:                  <a> TEXT </a>  add to
# +1.1206:               <input name=...>  antity
# +1.1206:               <input name=...>  quanti
# +1.1206:               <input name=...>  antit
# +1.1206:               <input name=...>  uanti
# +1.1206:               <input name=...>  uantit
# +1.1025:               <input name=...>  ntity
# +1.0853:               <input name=...>  ntity
#    ...
# -0.5887:  <input type=submit value=...>  go
# -0.6031:          <label> TEXT </label>  sort
# -0.6164:              <form action=...>  event
# -0.6693:        <form class=... id=...>  form
# -0.6751:        <form class=... id=...>  orm
# -0.6794:        <form class=... id=...>  form
# -0.7129:                  form elements  3 or more <input type=text>
# -0.7306:  <input type=submit value=...>  search
# -0.7330:                  form elements  has <input type=checkbox>
# -0.7370:               <input name=...>  email
# -0.7599:               <input name=...>   email
# -0.7599:               <input name=...>   emai
# -0.7905:               <input name=...>   s
# -0.7997:               <input name=...>  mail
# -0.8090:                  form elements  has <textarea>
# -0.8144:               <input name=...>  email
# -0.8482:                  form elements  <form method=post
# -0.9724:                  form elements  has <input type=email>
# -1.0591:                  form elements  exactly two <input type=password>
# -1.0601:               <input name=...>   q
# -1.1428:                  form elements  2 or 3 inputs
# -1.5610:                  form elements  <form method=get
# -1.5714:                  form elements  exactly one <input type=password>
# -1.6996:                  form elements  exactly two <input type=text>
# -2.4091:                           bias  bias
# --------------------------------------------------------------------------------
# other
# +1.9037:       <input class=... id=...>  from
# +1.8774:               <input name=...>  surl
# +1.8286:        <form class=... id=...>   xe
# +1.5331:               <input name=...>  code
# +1.5241:                  <a> TEXT </a>  conditions
# +1.4232:  <input type=submit value=...>  mentése
# +1.4232:  <input type=submit value=...>  keresés mentése
# +1.3458:                  form elements  no <input type=text>
# +1.2920:          <label> TEXT </label>  10
# +1.2010:                  form elements  no <input type=password>
# +1.0702:        <form class=... id=...>   add
# +1.0684:          <label> TEXT </label>  description
# +1.0561:  <input type=submit value=...>  lähetä
# +1.0528:              <form action=...>  ers#
# +1.0503:              <form action=...>  quest
# +1.0228:               <input name=...>   url
# +1.0016:                  form elements  has <input type=radio>
# +0.9991:        <form class=... id=...>  jump
# +0.9758:              <form action=...>  tiona
# +0.9742:  <input type=submit value=...>  continue
# +0.9582:          <label> TEXT </label>  zip
# +0.9567:              <form action=...>  event
# +0.9391:          <label> TEXT </label>  line
# +0.9233:        <form class=... id=...>  lect
# +0.9215:  <input type=submit value=...>  keresés
#    ...
# -0.9839:                  <a> TEXT </a>  forums
# -0.9851:          <label> TEXT </label>  search
# -0.9853:                  <a> TEXT </a>  statement
# -0.9922:                  form elements  has <select>
# -0.9995:          <label> TEXT </label>  year
# -1.0100:                  <a> TEXT </a>  affiliate
# -1.0182:               <input name=...>  bmit
# -1.0182:               <input name=...>  ubmit
# -1.0360:               <input name=...>  ubmit
# -1.0360:               <input name=...>  submit
# -1.0604:               <input name=...>  email
# -1.0635:               <input name=...>  submi
# -1.0763:               <input name=...>  mail
# -1.1114:               <input name=...>   qty
# -1.1731:                           bias  bias
# -1.2468:               <input name=...>  list
# -1.3486:                  form elements  has <input type=email>
# -1.4194:                  form elements  exactly one <input type=password>
# -1.4415:  <input type=submit value=...>  search
# -1.5393:              <form action=...>  login
# -1.6248:               <input name=...>   s
# -1.7549:          <label> TEXT </label>  sort
# -1.7812:                  form elements  exactly one <input type=text>
# -1.8463:                  form elements  has <textarea>
# -2.1209:               <input name=...>   q
# --------------------------------------------------------------------------------
# password/login recovery
# +2.2823:  <input type=submit value=...>  reset
# +2.2585:  <input type=submit value=...>  password
# +1.6524:  <input type=submit value=...>  priminti
# +1.5353:  <input type=submit value=...>  reset password
# +1.4207:               <input name=...>  mail
# +1.4095:          <label> TEXT </label>  email
# +1.3371:        <form class=... id=...>  pass
# +1.3290:  <input type=submit value=...>  odošli
# +1.2701:               <input name=...>  email
# +1.2522:              <form action=...>  asswo
# +1.2522:              <form action=...>  sswor
# +1.2522:              <form action=...>  asswor
# +1.2522:              <form action=...>  passwo
# +1.2522:              <form action=...>  passw
# +1.1759:              <form action=...>  ssword
# +1.1759:              <form action=...>  sword
# +1.1496:              <form action=...>  forgo
# +1.1496:              <form action=...>  forgot
# +1.1496:              <form action=...>  orgot
# +1.1474:               <input name=...>  email
# +1.1386:               <input name=...>  ogin
# +1.1386:               <input name=...>  login
# +1.0978:               <input name=...>   login
# +1.0978:               <input name=...>   logi
# +1.0669:  <input type=submit value=...>  次へ
#    ...
# -0.5274:  <input type=submit value=...>  search
# -0.5280:        <form class=... id=...>  _form
# -0.5342:                  form elements  exactly two <input type=password>
# -0.5486:              <form action=...>   sign
# -0.5565:              <form action=...>   signu
# -0.5690:  <input type=submit value=...>  account
# -0.6108:                  form elements  <form method=post
# -0.6604:  <input type=submit value=...>  sign
# -0.6921:               <input name=...>   qty
# -0.7182:  <input type=submit value=...>  register
# -0.7292:              <form action=...>  ignup
# -0.7292:              <form action=...>  signu
# -0.7292:              <form action=...>  signup
# -0.7906:                  form elements  3 or more <input type=text>
# -0.8365:  <input type=submit value=...>  подписаться
# -0.8700:  <input type=submit value=...>  subscribe
# -0.9046:               <input name=...>   q
# -0.9991:                  form elements  no <input type=text>
# -1.3562:                  form elements  has <input type=checkbox>
# -1.3566:                  form elements  has <input type=radio>
# -1.6993:                  form elements  has <select>
# -2.1396:                  form elements  <form method=get
# -2.2139:                  form elements  has <textarea>
# -2.7504:                           bias  bias
# -2.8671:                  form elements  exactly one <input type=password>
# --------------------------------------------------------------------------------
# registration
# +3.1442:                  form elements  exactly two <input type=password>
# +2.5176:  <input type=submit value=...>  register
# +1.7610:  <input type=submit value=...>  create
# +1.5648:  <input type=submit value=...>  registrovať
# +1.4722:              <form action=...>  regis
# +1.4620:              <form action=...>  egist
# +1.4620:              <form action=...>  regist
# +1.4344:              <form action=...>  giste
# +1.4344:              <form action=...>  gister
# +1.4344:              <form action=...>  egiste
# +1.4344:              <form action=...>  ister
# +1.3205:  <input type=submit value=...>  regisztráció
# +1.2145:                  form elements  has <input type=email>
# +1.1350:  <input type=submit value=...>  account
# +1.1040:                  form elements  3 or more <input type=text>
# +1.0955:  <input type=submit value=...>  зарегистрироваться
# +1.0511:              <form action=...>  ster#
# +1.0511:              <form action=...>  ster#
# +1.0511:              <form action=...>  ister#
# +1.0031:              <form action=...>  ter#
# +0.9893:              <form action=...>  signup
# +0.9893:              <form action=...>  ignup
# +0.9893:              <form action=...>  signu
# +0.9822:               <input name=...>  mailc
# +0.9822:               <input name=...>  emailc
#    ...
# -0.5713:              <form action=...>  ogin#
# -0.5713:              <form action=...>  gin#
# -0.5758:  <input type=submit value=...>  search
# -0.5792:        <form class=... id=...>  form
# -0.5860:  <input type=submit value=...>  submit
# -0.6138:  <input type=submit value=...>  reset password
# -0.6247:                  <a> TEXT </a>  forgot
# -0.6435:          <label> TEXT </label>  email
# -0.6730:                  form elements  has <input type=checkbox>
# -0.6799:  <input type=submit value=...>  reset
# -0.6807:                  <a> TEXT </a>  conditions
# -0.7044:                  form elements  2 or 3 inputs
# -0.7878:  <input type=submit value=...>  in
# -0.9114:                  <a> TEXT </a>  password
# -0.9172:              <form action=...>  login
# -0.9407:                  <a> TEXT </a>  пароль
# -0.9516:                           bias  bias
# -0.9766:  <input type=submit value=...>  password
# -1.0216:                  form elements  <form method=get
# -1.1181:                  form elements  exactly one <input type=text>
# -1.1554:                  form elements  exactly one <input type=password>
# -1.1902:  <input type=submit value=...>  login
# -1.5721:                  form elements  has <textarea>
# -1.6242:                  form elements  no <input type=text>
# -2.9906:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# search
# +3.0136:               <input name=...>   q
# +2.5323:               <input name=...>   s
# +2.0315:          <label> TEXT </label>  sort
# +1.8639:  <input type=submit value=...>  search
# +1.7980:              <form action=...>  &sid=
# +1.6596:                  form elements  has <select>
# +1.5276:               <input name=...>  earch
# +1.5276:               <input name=...>  searc
# +1.5276:               <input name=...>  search
# +1.4988:          <label> TEXT </label>  year
# +1.3742:              <form action=...>  search
# +1.3742:              <form action=...>  earch
# +1.3742:              <form action=...>  searc
# +1.3473:       <input class=... id=...>  arch
# +1.3071:        <form class=... id=...>  eform
# +1.3071:        <form class=... id=...>  efor
# +1.2918:               <input name=...>  text
# +1.2532:       <input class=... id=...>   q
# +1.2510:        <form class=... id=...>  earc
# +1.2510:        <form class=... id=...>  earch
# +1.2510:        <form class=... id=...>  arch
# +1.2510:        <form class=... id=...>  sear
# +1.2510:        <form class=... id=...>  searc
# +1.2480:               <input name=...>   searc
# +1.2480:               <input name=...>   sear
#    ...
# -0.7735:          <label> TEXT </label>  email
# -0.8059:  <input type=submit value=...>  sign
# -0.8110:        <form class=... id=...>  ect
# -0.8172:                  form elements  has <input type=radio>
# -0.8190:        <form class=... id=...>  lect
# -0.9089:              <form action=...>  event
# -0.9392:                  form elements  3 or more <input type=text>
# -1.0057:                  form elements  exactly two <input type=password>
# -1.0127:              <form action=...>   cart
# -1.0189:                  form elements  has <input type=email>
# -1.0371:               <input name=...>  surl
# -1.1591:  <input type=submit value=...>  submit
# -1.2916:               <input name=...>  email
# -1.3058:        <form class=... id=...>   xe
# -1.3100:       <input class=... id=...>  from
# -1.3892:                  form elements  no <input type=text>
# -1.3934:               <input name=...>  mail
# -1.5477:               <input name=...>   email
# -1.5477:               <input name=...>   emai
# -1.5511:               <input name=...>  email
# -1.6068:               <input name=...>   qty
# -1.8004:                  form elements  <form method=post
# -1.8370:                           bias  bias
# -1.9476:                  form elements  exactly one <input type=password>
# -2.1160:                  form elements  has <textarea>
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Compare results with "loginform" library
#
# It is not possible to compare the results with "loginform" library directly because loginform
#
# * always tries to return a login form even if the score is low;
# * only detects login forms;
# * in case of several forms returns a single form with the best score instead of deciding for each form whether to return it or not.
#
# So we used two approaches:
#
# 1. Use `loginform._form_score` with different thresholds; assume that if score is greater than or equal to a threshold `loginform` detected a login form.
# 2. Train the same model, but using features from loginform library (weights will be learned instead of being hardcoded as 'score' increments/decrements).

# %% [markdown]
# ### 1. loginform scores + thresholds
#
# * **score >= -100** means "simply treat all forms as login forms".
#
# * **score >= 0** all (or most) login forms are captured, but there are many false positives.
#   It is only slightly better than treating all forms as login forms.
#
# * **score >= 10** F1 score is the best among all thresholds,
#   but the quality is significantly worse than F1 of ML-based models.
#
# * **score >= 20** ~90% of detected login forms are correct, but most
#   login forms are not detected. Also, ~90% number is still lower than what ML-based models give us.

# %%
# %%time 
import loginform

def labels_to_binary(y):
    """ Convert labels to 2-classes: login forms and non-login forms """
    return [tp == 'login' for tp in y]

    
def predict_loginform(X, threshold):
    """
    Return if forms are login or not using loginform
    library scores and a threshold.
    """
    return [
        (loginform._form_score(form) >= threshold)
        for form in X
    ]


def print_threshold_metrics(X, y, threshold):
    y = labels_to_binary(y)
    y_pred = predict_loginform(X, threshold)

    precision, recall, f1, support = precision_recall_fscore_support(y, y_pred, pos_label=True)
    print(
        "score >= %4d:    precision = %0.3f    recall = %0.3f    F1 = %0.3f" % (
        threshold, precision[1], recall[1], f1[1]
    ))


for threshold in [-100, -10, 0, 10, 20, 30]:
    print_threshold_metrics(X, y, threshold)
# Out:
# score >= -100:    precision = 0.178    recall = 1.000    F1 = 0.302
# score >=  -10:    precision = 0.201    recall = 0.973    F1 = 0.333
# score >=    0:    precision = 0.321    recall = 0.968    F1 = 0.483
# score >=   10:    precision = 0.708    recall = 0.869    F1 = 0.780
# score >=   20:    precision = 0.854    recall = 0.317    F1 = 0.462
# score >=   30:    precision = 1.000    recall = 0.009    F1 = 0.018
# CPU times: user 2.3 s, sys: 6.62 ms, total: 2.31 s
# Wall time: 2.37 s
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 2. Use loginform features, but autodetect scores
#
# The following ML-based model is trained using original loginform features (conditions used to increase or decrease the score). Roughly speaking, it uses the same information as loginform library, but instead of hardcoding `score += 10` and `score -= 10` the numbers are adjusted based on training data.
#
# Note that the login form detection quality is significantly better than the quality of threshold-based model; it is only slightly worse than the quality of a "full" forms detection model. This means original loginform features are quite good at detecting login forms. But for other form types these features are not enough: other scores are bad.

# %%
# %%time

LOGINFORM_FEATURES = [
    ('bias', features.Bias(), DictVectorizer()),
    ('loginform', features.OldLoginformFeatures(), DictVectorizer())
]
# loginform_clf = LinearSVC(C=0.5, fit_intercept=False)
loginform_clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0)

model = make_pipeline(
    _create_feature_union(LOGINFORM_FEATURES), 
    loginform_clf,
)

formtype_model.print_classification_report(annotations, n_folds=10, model=model)

model.fit(X, y)
print_informative_features(LOGINFORM_FEATURES, loginform_clf, 25)
# Out:
#                  precision    recall  f1-score   support
#
#          search       0.55      0.80      0.65       364
#           login       0.92      0.95      0.93       221
#    registration       0.94      0.67      0.78       153
# contact/comment       0.48      0.74      0.58       120
#           other       0.38      0.59      0.46       122
#
#     avg / total       0.66      0.78      0.70       980
#
# 61.6% forms are classified correctly.
# contact/comment
# +3.6031:                      loginform  typecount_password_0
# +2.9595:                      loginform  typecount_text_gt1
# +0.1378:                      loginform  typecount_text_0
# +0.0472:                      loginform  typecount_radio_gt0
# -1.3174:                      loginform  typecount_checkbox_gt1
# -1.4609:                      loginform  typecount_password_eq1
# -1.5214:                      loginform  2_or_3_inputs
# -6.4988:                           bias  bias
# --------------------------------------------------------------------------------
# join mailing list
# +2.4581:                      loginform  typecount_password_0
# +1.1900:                      loginform  typecount_checkbox_gt1
# +0.3436:                      loginform  2_or_3_inputs
# -0.2444:                      loginform  typecount_text_0
# -0.7037:                      loginform  typecount_text_gt1
# -0.7194:                      loginform  typecount_radio_gt0
# -1.9828:                      loginform  typecount_password_eq1
# -4.4470:                           bias  bias
# --------------------------------------------------------------------------------
# login
# +5.6877:                      loginform  typecount_password_eq1
# +0.9158:                      loginform  typecount_text_0
# +0.3679:                      loginform  2_or_3_inputs
# -1.8400:                      loginform  typecount_password_0
# -1.9595:                      loginform  typecount_checkbox_gt1
# -2.0258:                      loginform  typecount_radio_gt0
# -2.3173:                      loginform  typecount_text_gt1
# -2.7058:                           bias  bias
# --------------------------------------------------------------------------------
# order/add to cart
# +1.7238:                      loginform  typecount_password_0
# +0.4019:                      loginform  typecount_radio_gt0
# +0.0433:                      loginform  typecount_text_0
# -0.5080:                      loginform  2_or_3_inputs
# -0.8301:                      loginform  typecount_checkbox_gt1
# -1.0046:                      loginform  typecount_text_gt1
# -2.0603:                      loginform  typecount_password_eq1
# -4.0578:                           bias  bias
# --------------------------------------------------------------------------------
# other
# +2.5668:                      loginform  typecount_text_0
# +2.0095:                      loginform  typecount_password_0
# +0.9709:                      loginform  typecount_text_gt1
# +0.8657:                      loginform  typecount_radio_gt0
# +0.0168:                      loginform  typecount_checkbox_gt1
# -0.1392:                      loginform  2_or_3_inputs
# -2.0844:                      loginform  typecount_password_eq1
# -5.0778:                           bias  bias
# --------------------------------------------------------------------------------
# password/login recovery
# +1.2266:                      loginform  typecount_password_0
# +0.7331:                      loginform  2_or_3_inputs
# -0.3934:                      loginform  typecount_text_gt1
# -0.6895:                      loginform  typecount_text_0
# -2.0991:                      loginform  typecount_checkbox_gt1
# -2.3291:                      loginform  typecount_radio_gt0
# -2.7606:                      loginform  typecount_password_eq1
# -3.3844:                           bias  bias
# --------------------------------------------------------------------------------
# registration
# +2.1635:                      loginform  typecount_text_gt1
# +1.5013:                           bias  bias
# +0.6909:                      loginform  typecount_radio_gt0
# +0.6713:                      loginform  typecount_checkbox_gt1
# +0.5782:                      loginform  typecount_text_0
# +0.0581:                      loginform  2_or_3_inputs
# -4.3791:                      loginform  typecount_password_eq1
# -5.9839:                      loginform  typecount_password_0
# --------------------------------------------------------------------------------
# search
# +3.7242:                      loginform  typecount_password_0
# +0.6919:                      loginform  typecount_checkbox_gt1
# -0.0865:                      loginform  2_or_3_inputs
# -0.3891:                      loginform  typecount_radio_gt0
# -1.2802:                      loginform  typecount_text_0
# -2.1901:                      loginform  typecount_text_gt1
# -2.4592:                      loginform  typecount_password_eq1
# -3.4670:                           bias  bias
# --------------------------------------------------------------------------------
# CPU times: user 4.44 s, sys: 7.89 ms, total: 4.44 s
# Wall time: 4.46 s
