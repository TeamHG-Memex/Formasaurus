# %%
import sys
sys.path.insert(0, '..')

from formasaurus import formtype_features as features
from formasaurus import formtype_model
from formasaurus.storage import Storage, load_html

# %% [markdown]
# ### Available training data

# %%
storage = Storage("../formasaurus/data")
storage.check()
storage.print_form_type_counts(simplify=True)
# Out:
# Checking: 100%|##########################| 832/832 [00:03<00:00, 269.34 files/s]
# Status: OK
# Annotated HTML forms (simplified classes):
#
# 364   search                    (s)
# 222   login                     (l)
# 153   registration              (r)
# 122   other                     (o)
# 120   contact/comment           (c)
# 107   join mailing list         (m)
# 95    password/login recovery   (p)
# 62    order/add to cart         (b)
#
# Total form count: 1245

# %% [markdown]
# ## Load training / evaluation data

# %%
annotations = list(storage.iter_annotations(
    simplify_form_types=True,
    simplify_field_types=True,
    verbose=True,
    leave=True,        
))
X, y = formtype_model.get_Xy(annotations, full_type_names=True)
# Out:
# Loading: 832 files [00:03, 223.44 files/s]

# %% [markdown]
# ## Ideas for useful features
#
# ### Search forms
#
# * a single query field
# * a field named "q" or "s"
# * "search" in URL
# * "search" in submit button text (submit value)
# * "search" in form css class or id
# * no password field
# * method == GET?
#
# ### Login forms
#
# * username or email and password
# * 2 passwords - likely not a login form
# * "login" or "sign in" (or variations) in URL
# * "login" or "sign in" (or variations) in form css class or id
# * "login" or "sign in" in submit button text
# * "Remember me" checkbox (or any single checkbox)
# * no select elements
# * no textarea elements
# * openid?
# * method == POST
#
# ### Registration forms
#
# * 2 passwords
# * "register" / "sign up" in URL, form css class / id or submit button text
# * "agree" checkbox
# * email
# * username
# * method == POST
#
# ### Contact forms
#
# * feedback in URL/class
# * textarea
# * "Send" button
# * email
# * method == POST
#
# ### Password reset
#
# * a single email or username field
# * "password" in URL/css class/ submit button text
#
# ### Join Mailing List
#
# * a single email field
# * subscribe/join/newsletter words
# * a short form
#
# The main problem with "join mailing list" forms is to distinguish them from search forms.
#
# ## How to handle them
#
# Instead of hardcoding the features above many of them are generalized. For exmaple, instead of writing "search in URL" we extract all 5-character substrings from the URL and use "`urlsubstring<N>` in URL" as features. There are some disadvantages in this approach, but it provides a good starting point.
#
# The feature extractors are stored in formtype.features module.

# %%
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report, precision_recall_fscore_support

# %%
# %%time
# reload(features)
from formasaurus.formtype_model import _create_feature_union
# ======= define the model ========

# features should be kept in sync with formasaurus.formtype_features
# a list of 3-tuples with default features:
# (feature_name, form_transformer, vectorizer)
FEATURES = [    
    (
        # bias feature is for easier debugging, it should be removed
        # in production!
        "bias",  
        features.Bias(),
        DictVectorizer(),  
    ),
    
    (
        "form elements",
        features.FormElements(),
        DictVectorizer()
    ),
    (
        "<input type=submit value=...>",
        features.SubmitText(),
        CountVectorizer(ngram_range=(1,2), min_df=1, binary=True)
    ),
    (
        "<a> TEXT </a>",
        features.FormLinksText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=4, binary=True,
                        stop_words={'and', 'or', 'of'})
    ),
    (
        "<label> TEXT </label>",
        features.FormLabelText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=3, binary=True,
                        stop_words="english")
    ),

    (
        "<form action=...>",
        features.FormUrl(),
        TfidfVectorizer(ngram_range=(5,6), min_df=4, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<form class=... id=...>",
        features.FormCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input class=... id=...>",
        features.FormInputCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=5, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input name=...>",
        features.FormInputNames(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input title=...>",
        features.FormInputTitle(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
]


# clf = SGDClassifier(
#     penalty='elasticnet', 
#     loss='log', 
#     alpha=0.0002,
#     fit_intercept=False, 
#     shuffle=True, 
#     random_state=0,
#     n_iter=50,
# )
clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0, tol=0.01)

# clf = LinearSVC(C=0.5, random_state=0, fit_intercept=False)
model = Pipeline([
    ('fe', _create_feature_union(FEATURES)),
    ('clf', clf),
])

formtype_model.print_classification_report(annotations, n_folds=10, model=model)
# Out:
#                          precision    recall  f1-score   support
#
#                  search       0.91      0.96      0.93       364
#                   login       0.96      0.96      0.96       222
#            registration       0.96      0.85      0.90       153
# password/login recovery       0.87      0.86      0.87        95
#         contact/comment       0.85      0.94      0.89       120
#       join mailing list       0.89      0.88      0.88       107
#       order/add to cart       0.93      0.66      0.77        62
#                   other       0.67      0.70      0.69       122
#
#             avg / total       0.89      0.89      0.89      1245
#
# 89.0% forms are classified correctly.
# CPU times: user 12.6 s, sys: 63 ms, total: 12.7 s
# Wall time: 12.7 s

# %% [markdown]
# ## Check what classifier learned
#
# For linear classifiers like Logistic Regression or an SVM without a kernel we can check coefficient values to understand better how the decision is made.
#
# For correlated features (notably, n-grams) weight will be spread across all correlated features, so just checking coefficients is not enough, but looking at them is useful anyways.

# %%
def get_informative_features(vectorizers, clf, class_labels, N):
    """
    Return text with features with the highest absolute coefficient
    values, per class.
    """
    feature_names = []
    for vec_name, vec in vectorizers:
        feature_names.extend(
            "%30s  %s" % (vec_name, name) for name in vec.get_feature_names()
        )
    features_by_class = []
    for i, class_label in enumerate(class_labels):
        topN = np.argsort(clf.coef_[i])[-N:]
        bottomN = np.argsort(clf.coef_[i])[:N]
        res = []

        for j in reversed(topN):
            coef = clf.coef_[i][j]
            if coef > 0:
                res.append("+%0.4f: %s" % (coef, feature_names[j]))

        if (len(topN) >= N) or (len(bottomN) >= N):
            res.append("   ...")

        for j in reversed(bottomN):
            coef = clf.coef_[i][j]
            if coef < 0:
                res.append("%0.4f: %s" % (coef, feature_names[j]))
        features_by_class.append((class_label, '\n'.join(res)))
    return features_by_class


def print_informative_features(features, clf, top, classes=None, class_map=None):
    vectorizers = [(name, vec) for (name, fe, vec) in features]
    feat_info = get_informative_features(vectorizers, clf, clf.classes_, top)
    for cls, report in feat_info:
        if classes is not None and cls not in classes:
            continue
        if class_map is not None:
            print(class_map[cls])
        else:
            print(cls)
        print(report)
        print("-"*80)

# %%
model.fit(X, y)
print_informative_features(FEATURES, clf, 25)
# Out:
# contact/comment
# +5.7047:                  form elements  has <textarea>
# +2.4165:          <label> TEXT </label>  question
# +1.6249:              <form action=...>   kont
# +1.5064:                  <a> TEXT </a>  agent
# +1.5023:                  <a> TEXT </a>  affiliate
# +1.4561:                  <a> TEXT </a>  mobile
# +1.4456:                  <a> TEXT </a>  forums
# +1.4300:                  <a> TEXT </a>  privacy statement
# +1.3853:                  <a> TEXT </a>  statement
# +1.2378:                  <a> TEXT </a>  contact
# +1.2010:          <label> TEXT </label>  message
# +1.1773:  <input type=submit value=...>  send
# +1.1518:                  <a> TEXT </a>  contact us
# +1.0653:                  <a> TEXT </a>  us
# +0.8713:                  <a> TEXT </a>  privacy
# +0.8337:        <form class=... id=...>  ques
# +0.8337:        <form class=... id=...>  quest
# +0.8337:        <form class=... id=...>  uest
# +0.7949:                  <a> TEXT </a>  http
# +0.7949:                  <a> TEXT </a>  http www
# +0.7931:          <label> TEXT </label>  comments
# +0.7820:        <form class=... id=...>  new_
# +0.7761:          <label> TEXT </label>  email message
# +0.7518:        <form class=... id=...>  t-for
# +0.7227:              <form action=...>   send
#    ...
# -0.6002:        <form class=... id=...>   web
# -0.6036:  <input type=submit value=...>  crear
# -0.6093:        <form class=... id=...>   ord
# -0.6216:  <input type=submit value=...>  now
# -0.6263:              <form action=...>  .aspx
# -0.6448:        <form class=... id=...>  site
# -0.6522:  <input type=submit value=...>  next
# -0.6587:        <form class=... id=...>  ine
# -0.6949:               <input name=...>   mail
# -0.7081:          <label> TEXT </label>  login
# -0.7184:               <input name=...>   mail
# -0.7209:              <form action=...>  entry
# -0.7577:              <form action=...>  tiona
# -0.8362:  <input type=submit value=...>  registrovať
# -0.9821:  <input type=submit value=...>  корзину отправить
# -0.9821:  <input type=submit value=...>  корзину
# -1.0001:                  form elements  has <input type=checkbox>
# -1.0979:                  form elements  exactly one <input type=password>
# -1.1312:  <input type=submit value=...>  lähetä
# -1.1847:        <form class=... id=...>   add
# -1.3446:                  form elements  <form method=post
# -1.5250:                  form elements  <form method=get
# -1.7971:                  form elements  exactly one <input type=text>
# -2.4403:                  form elements  exactly two <input type=password>
# -2.8696:                           bias  bias
# --------------------------------------------------------------------------------
# join mailing list
# +1.6450:               <input name=...>   go
# +1.5434:  <input type=submit value=...>  subscribe
# +1.4717:  <input type=submit value=...>  подписаться
# +1.4145:        <form class=... id=...>  mail
# +1.4101:               <input name=...>   emai
# +1.4101:               <input name=...>   email
# +1.2601:               <input name=...>  news
# +1.1599:        <form class=... id=...>  news
# +1.1290:  <input type=submit value=...>  cadastrar
# +1.1240:               <input name=...>   zip
# +1.1069:               <input name=...>  email
# +1.0609:                  <a> TEXT </a>  list
# +1.0256:               <input name=...>   em
# +1.0011:  <input type=submit value=...>  up
# +0.9916:        <form class=... id=...>  ubsc
# +0.9916:        <form class=... id=...>  bscr
# +0.9916:        <form class=... id=...>  bscri
# +0.9916:        <form class=... id=...>  ubscr
# +0.9916:        <form class=... id=...>  subsc
# +0.9916:        <form class=... id=...>  subs
# +0.9785:        <form class=... id=...>  scri
# +0.9651:                  form elements  has <input type=email>
# +0.9158:        <form class=... id=...>  lett
# +0.9158:        <form class=... id=...>  lette
# +0.9158:        <form class=... id=...>  ewsle
#    ...
# -0.5800:        <form class=... id=...>  earch
# -0.5800:        <form class=... id=...>  searc
# -0.5800:        <form class=... id=...>  arch
# -0.5800:        <form class=... id=...>  earc
# -0.5800:        <form class=... id=...>  sear
# -0.5914:              <form action=...>   auth
# -0.6020:                  form elements  exactly two <input type=text>
# -0.6555:               <input name=...>   s
# -0.6672:          <label> TEXT </label>  adresse
# -0.6714:               <input name=...>   qty
# -0.7356:  <input type=submit value=...>  reset
# -0.7451:  <input type=submit value=...>  password
# -0.7456:  <input type=submit value=...>  send
# -0.8019:          <label> TEXT </label>  password
# -0.9132:          <label> TEXT </label>  mail
# -1.0151:                  form elements  <form method=post
# -1.0373:               <input name=...>   q
# -1.2096:                  form elements  no <input type=text>
# -1.3052:                  form elements  has <select>
# -1.4406:          <label> TEXT </label>  email
# -1.6305:                  form elements  exactly two <input type=password>
# -1.6501:                  form elements  <form method=get
# -1.8706:                  form elements  exactly one <input type=password>
# -2.2601:                  form elements  has <textarea>
# -2.6653:                           bias  bias
# --------------------------------------------------------------------------------
# login
# +3.4824:                  form elements  exactly one <input type=password>
# +3.0518:              <form action=...>  login
# +1.8492:  <input type=submit value=...>  submit
# +1.8024:  <input type=submit value=...>  login
# +1.4129:  <input type=submit value=...>  in
# +1.1301:  <input type=submit value=...>  sign in
# +1.0719:              <form action=...>  openi
# +1.0719:              <form action=...>  penid
# +1.0719:              <form action=...>  openid
# +0.9943:  <input type=submit value=...>  войти
# +0.8772:  <input type=submit value=...>  sign
# +0.8643:                  <a> TEXT </a>  password
# +0.8240:  <input type=submit value=...>  войти войти
# +0.7895:                  form elements  no <input type=text>
# +0.7525:          <label> TEXT </label>  remember
# +0.7180:        <form class=... id=...>   cer
# +0.7160:              <form action=...>  login#
# +0.7160:              <form action=...>  ogin#
# +0.7160:              <form action=...>  gin#
# +0.7160:              <form action=...>  ogin#
# +0.7065:              <form action=...>  dlogi
# +0.7065:              <form action=...>  dlogin
# +0.7065:              <form action=...>  enidl
# +0.7065:              <form action=...>  idlogi
# +0.7065:              <form action=...>  enidlo
#    ...
# -0.4937:               <input name=...>   email
# -0.5260:  <input type=submit value=...>  register now
# -0.5292:               <input name=...>  email
# -0.5313:  <input type=submit value=...>  now
# -0.5474:          <label> TEXT </label>  mail
# -0.5789:  <input type=submit value=...>  create account
# -0.5985:                  <a> TEXT </a>  terms service
# -0.6008:               <input name=...>   q
# -0.6195:                  <a> TEXT </a>  service
# -0.6344:                  <a> TEXT </a>  terms
# -0.7426:                  <a> TEXT </a>  com
# -0.7458:  <input type=submit value=...>  account
# -0.8204:  <input type=submit value=...>  create
# -0.8308:                  form elements  <form method=get
# -0.9539:                  form elements  has <textarea>
# -0.9764:  <input type=submit value=...>  regisztráció
# -0.9843:                  form elements  has <input type=radio>
# -0.9944:  <input type=submit value=...>  зарегистрироваться
# -1.0744:  <input type=submit value=...>  register
# -1.2492:                           bias  bias
# -1.4652:                  form elements  3 or more <input type=text>
# -1.6444:                  form elements  exactly two <input type=password>
# -2.0472:                  form elements  has <input type=email>
# -2.0521:                  form elements  has <select>
# -3.0844:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# order/add to cart
# +3.2273:               <input name=...>   qty
# +2.2659:              <form action=...>   cart
# +1.9485:  <input type=submit value=...>  заказ
# +1.6613:                  <a> TEXT </a>  email
# +1.6564:               <input name=...>  list
# +1.6211:              <form action=...>   prod
# +1.3928:               <input name=...>  quant
# +1.3702:               <input name=...>  oncode
# +1.3702:               <input name=...>  oncod
# +1.2963:               <input name=...>  ncode
# +1.2963:               <input name=...>  ncode
# +1.2336:  <input type=submit value=...>  оплатить
# +1.2336:  <input type=submit value=...>  оплатить заказ
# +1.1703:          <label> TEXT </label>  quantity
# +1.1324:                  <a> TEXT </a>  to
# +1.1277:                  form elements  has <select>
# +1.1250:  <input type=submit value=...>  acquista
# +1.1220:                  <a> TEXT </a>  add to
# +1.1205:               <input name=...>  uantit
# +1.1205:               <input name=...>  antit
# +1.1205:               <input name=...>  antity
# +1.1205:               <input name=...>  uanti
# +1.1205:               <input name=...>  quanti
# +1.1024:               <input name=...>  ntity
# +1.0852:               <input name=...>  ntity
#    ...
# -0.5888:  <input type=submit value=...>  go
# -0.6032:          <label> TEXT </label>  sort
# -0.6165:              <form action=...>  event
# -0.6693:        <form class=... id=...>  form
# -0.6751:        <form class=... id=...>  orm
# -0.6799:        <form class=... id=...>  form
# -0.7144:                  form elements  3 or more <input type=text>
# -0.7303:  <input type=submit value=...>  search
# -0.7343:                  form elements  has <input type=checkbox>
# -0.7370:               <input name=...>  email
# -0.7600:               <input name=...>   emai
# -0.7600:               <input name=...>   email
# -0.7906:               <input name=...>   s
# -0.7997:               <input name=...>  mail
# -0.8084:                  form elements  has <textarea>
# -0.8144:               <input name=...>  email
# -0.8485:                  form elements  <form method=post
# -0.9721:                  form elements  has <input type=email>
# -1.0582:                  form elements  exactly two <input type=password>
# -1.0602:               <input name=...>   q
# -1.1429:                  form elements  2 or 3 inputs
# -1.5612:                  form elements  <form method=get
# -1.5740:                  form elements  exactly one <input type=password>
# -1.6992:                  form elements  exactly two <input type=text>
# -2.4097:                           bias  bias
# --------------------------------------------------------------------------------
# other
# +1.9037:       <input class=... id=...>  from
# +1.8773:               <input name=...>  surl
# +1.8286:        <form class=... id=...>   xe
# +1.5334:               <input name=...>  code
# +1.5245:                  <a> TEXT </a>  conditions
# +1.4233:  <input type=submit value=...>  keresés mentése
# +1.4233:  <input type=submit value=...>  mentése
# +1.3459:                  form elements  no <input type=text>
# +1.2918:          <label> TEXT </label>  10
# +1.2020:                  form elements  no <input type=password>
# +1.0703:        <form class=... id=...>   add
# +1.0684:          <label> TEXT </label>  description
# +1.0561:  <input type=submit value=...>  lähetä
# +1.0527:              <form action=...>  ers#
# +1.0502:              <form action=...>  quest
# +1.0229:               <input name=...>   url
# +1.0021:                  form elements  has <input type=radio>
# +0.9992:        <form class=... id=...>  jump
# +0.9757:              <form action=...>  tiona
# +0.9741:  <input type=submit value=...>  continue
# +0.9583:          <label> TEXT </label>  zip
# +0.9566:              <form action=...>  event
# +0.9392:          <label> TEXT </label>  line
# +0.9233:        <form class=... id=...>  lect
# +0.9216:  <input type=submit value=...>  keresés
#    ...
# -0.9848:                  <a> TEXT </a>  forums
# -0.9851:          <label> TEXT </label>  search
# -0.9863:                  <a> TEXT </a>  statement
# -0.9926:                  form elements  has <select>
# -0.9995:          <label> TEXT </label>  year
# -1.0110:                  <a> TEXT </a>  affiliate
# -1.0181:               <input name=...>  ubmit
# -1.0181:               <input name=...>  bmit
# -1.0359:               <input name=...>  submit
# -1.0359:               <input name=...>  ubmit
# -1.0603:               <input name=...>  email
# -1.0634:               <input name=...>  submi
# -1.0762:               <input name=...>  mail
# -1.1114:               <input name=...>   qty
# -1.1735:                           bias  bias
# -1.2461:               <input name=...>  list
# -1.3485:                  form elements  has <input type=email>
# -1.4211:                  form elements  exactly one <input type=password>
# -1.4414:  <input type=submit value=...>  search
# -1.5393:              <form action=...>  login
# -1.6248:               <input name=...>   s
# -1.7547:          <label> TEXT </label>  sort
# -1.7813:                  form elements  exactly one <input type=text>
# -1.8461:                  form elements  has <textarea>
# -2.1208:               <input name=...>   q
# --------------------------------------------------------------------------------
# password/login recovery
# +2.2791:  <input type=submit value=...>  reset
# +2.2555:  <input type=submit value=...>  password
# +1.6552:  <input type=submit value=...>  priminti
# +1.5349:  <input type=submit value=...>  reset password
# +1.4216:               <input name=...>  mail
# +1.4083:          <label> TEXT </label>  email
# +1.3379:        <form class=... id=...>  pass
# +1.3282:  <input type=submit value=...>  odošli
# +1.2716:               <input name=...>  email
# +1.2530:              <form action=...>  passw
# +1.2530:              <form action=...>  passwo
# +1.2530:              <form action=...>  sswor
# +1.2530:              <form action=...>  asswor
# +1.2530:              <form action=...>  asswo
# +1.1767:              <form action=...>  sword
# +1.1767:              <form action=...>  ssword
# +1.1495:              <form action=...>  forgot
# +1.1495:              <form action=...>  forgo
# +1.1495:              <form action=...>  orgot
# +1.1485:               <input name=...>  email
# +1.1360:               <input name=...>  login
# +1.1360:               <input name=...>  ogin
# +1.0991:               <input name=...>   logi
# +1.0991:               <input name=...>   login
# +1.0666:  <input type=submit value=...>  次へ
#    ...
# -0.5267:  <input type=submit value=...>  search
# -0.5274:        <form class=... id=...>  _form
# -0.5324:                  form elements  exactly two <input type=password>
# -0.5474:              <form action=...>   sign
# -0.5553:              <form action=...>   signu
# -0.5687:  <input type=submit value=...>  account
# -0.6057:                  form elements  <form method=post
# -0.6595:  <input type=submit value=...>  sign
# -0.6912:               <input name=...>   qty
# -0.7177:  <input type=submit value=...>  register
# -0.7281:              <form action=...>  signup
# -0.7281:              <form action=...>  signu
# -0.7281:              <form action=...>  ignup
# -0.7864:                  form elements  3 or more <input type=text>
# -0.8368:  <input type=submit value=...>  подписаться
# -0.8690:  <input type=submit value=...>  subscribe
# -0.9040:               <input name=...>   q
# -0.9910:                  form elements  no <input type=text>
# -1.3537:                  form elements  has <input type=checkbox>
# -1.3566:                  form elements  has <input type=radio>
# -1.6953:                  form elements  has <select>
# -2.1420:                  form elements  <form method=get
# -2.2118:                  form elements  has <textarea>
# -2.7477:                           bias  bias
# -2.8691:                  form elements  exactly one <input type=password>
# --------------------------------------------------------------------------------
# registration
# +3.1553:                  form elements  exactly two <input type=password>
# +2.5143:  <input type=submit value=...>  register
# +1.7614:  <input type=submit value=...>  create
# +1.5616:  <input type=submit value=...>  registrovať
# +1.4739:              <form action=...>  regis
# +1.4635:              <form action=...>  regist
# +1.4635:              <form action=...>  egist
# +1.4355:              <form action=...>  giste
# +1.4355:              <form action=...>  gister
# +1.4355:              <form action=...>  ister
# +1.4355:              <form action=...>  egiste
# +1.3142:  <input type=submit value=...>  regisztráció
# +1.2229:                  form elements  has <input type=email>
# +1.1371:  <input type=submit value=...>  account
# +1.0963:  <input type=submit value=...>  зарегистрироваться
# +1.0892:                  form elements  3 or more <input type=text>
# +1.0521:              <form action=...>  ster#
# +1.0521:              <form action=...>  ster#
# +1.0521:              <form action=...>  ister#
# +1.0040:              <form action=...>  ter#
# +0.9866:              <form action=...>  signup
# +0.9866:              <form action=...>  signu
# +0.9866:              <form action=...>  ignup
# +0.9810:               <input name=...>  emailc
# +0.9810:               <input name=...>  mailc
#    ...
# -0.5715:              <form action=...>  ogin#
# -0.5715:              <form action=...>  ogin#
# -0.5717:  <input type=submit value=...>  search
# -0.5760:  <input type=submit value=...>  submit
# -0.5885:        <form class=... id=...>  form
# -0.6094:  <input type=submit value=...>  reset password
# -0.6151:                  <a> TEXT </a>  forgot
# -0.6482:          <label> TEXT </label>  email
# -0.6754:  <input type=submit value=...>  reset
# -0.6775:                  <a> TEXT </a>  conditions
# -0.6818:                  form elements  has <input type=checkbox>
# -0.7101:                  form elements  2 or 3 inputs
# -0.7876:  <input type=submit value=...>  in
# -0.8990:                  <a> TEXT </a>  password
# -0.9133:              <form action=...>  login
# -0.9426:                  <a> TEXT </a>  пароль
# -0.9440:                           bias  bias
# -0.9732:  <input type=submit value=...>  password
# -1.0133:                  form elements  <form method=get
# -1.1063:                  form elements  exactly one <input type=text>
# -1.1649:                  form elements  exactly one <input type=password>
# -1.2750:  <input type=submit value=...>  login
# -1.5632:                  form elements  has <textarea>
# -1.6221:                  form elements  no <input type=text>
# -2.9856:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# search
# +3.0135:               <input name=...>   q
# +2.5323:               <input name=...>   s
# +2.0315:          <label> TEXT </label>  sort
# +1.8639:  <input type=submit value=...>  search
# +1.7978:              <form action=...>  &sid=
# +1.6596:                  form elements  has <select>
# +1.5274:               <input name=...>  earch
# +1.5274:               <input name=...>  search
# +1.5274:               <input name=...>  searc
# +1.4988:          <label> TEXT </label>  year
# +1.3743:              <form action=...>  earch
# +1.3743:              <form action=...>  search
# +1.3743:              <form action=...>  searc
# +1.3473:       <input class=... id=...>  arch
# +1.3071:        <form class=... id=...>  efor
# +1.3071:        <form class=... id=...>  eform
# +1.2918:               <input name=...>  text
# +1.2533:       <input class=... id=...>   q
# +1.2510:        <form class=... id=...>  searc
# +1.2510:        <form class=... id=...>  sear
# +1.2510:        <form class=... id=...>  arch
# +1.2510:        <form class=... id=...>  earc
# +1.2510:        <form class=... id=...>  earch
# +1.2480:               <input name=...>   searc
# +1.2480:               <input name=...>   sear
#    ...
# -0.7735:          <label> TEXT </label>  email
# -0.8059:  <input type=submit value=...>  sign
# -0.8110:        <form class=... id=...>  ect
# -0.8171:                  form elements  has <input type=radio>
# -0.8190:        <form class=... id=...>  lect
# -0.9088:              <form action=...>  event
# -0.9395:                  form elements  3 or more <input type=text>
# -1.0058:                  form elements  exactly two <input type=password>
# -1.0126:              <form action=...>   cart
# -1.0183:                  form elements  has <input type=email>
# -1.0371:               <input name=...>  surl
# -1.1587:  <input type=submit value=...>  submit
# -1.2916:               <input name=...>  email
# -1.3056:        <form class=... id=...>   xe
# -1.3097:       <input class=... id=...>  from
# -1.3891:                  form elements  no <input type=text>
# -1.3934:               <input name=...>  mail
# -1.5475:               <input name=...>   emai
# -1.5475:               <input name=...>   email
# -1.5511:               <input name=...>  email
# -1.6066:               <input name=...>   qty
# -1.8007:                  form elements  <form method=post
# -1.8374:                           bias  bias
# -1.9482:                  form elements  exactly one <input type=password>
# -2.1162:                  form elements  has <textarea>
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Compare results with "loginform" library
#
# It is not possible to compare the results with "loginform" library directly because loginform
#
# * always tries to return a login form even if the score is low;
# * only detects login forms;
# * in case of several forms returns a single form with the best score instead of deciding for each form whether to return it or not.
#
# So we used two approaches:
#
# 1. Use `loginform._form_score` with different thresholds; assume that if score is greater than or equal to a threshold `loginform` detected a login form.
# 2. Train the same model, but using features from loginform library (weights will be learned instead of being hardcoded as 'score' increments/decrements).

# %% [markdown]
# ### 1. loginform scores + thresholds
#
# * **score >= -100** means "simply treat all forms as login forms".
#
# * **score >= 0** all (or most) login forms are captured, but there are many false positives.
#   It is only slightly better than treating all forms as login forms.
#
# * **score >= 10** F1 score is the best among all thresholds,
#   but the quality is significantly worse than F1 of ML-based models.
#
# * **score >= 20** ~90% of detected login forms are correct, but most
#   login forms are not detected. Also, ~90% number is still lower than what ML-based models give us.

# %%
# %%time 
import loginform

def labels_to_binary(y):
    """ Convert labels to 2-classes: login forms and non-login forms """
    return [tp == 'login' for tp in y]

    
def predict_loginform(X, threshold):
    """
    Return if forms are login or not using loginform
    library scores and a threshold.
    """
    return [
        (loginform._form_score(form) >= threshold)
        for form in X
    ]


def print_threshold_metrics(X, y, threshold):
    y = labels_to_binary(y)
    y_pred = predict_loginform(X, threshold)

    precision, recall, f1, support = precision_recall_fscore_support(y, y_pred, pos_label=True)
    print(
        "score >= %4d:    precision = %0.3f    recall = %0.3f    F1 = %0.3f" % (
        threshold, precision[1], recall[1], f1[1]
    ))


for threshold in [-100, -10, 0, 10, 20, 30]:
    print_threshold_metrics(X, y, threshold)
# Out:
# score >= -100:    precision = 0.178    recall = 1.000    F1 = 0.303
# score >=  -10:    precision = 0.201    recall = 0.973    F1 = 0.334
# score >=    0:    precision = 0.322    recall = 0.968    F1 = 0.484
# score >=   10:    precision = 0.710    recall = 0.869    F1 = 0.781
# score >=   20:    precision = 0.855    recall = 0.320    F1 = 0.466
# score >=   30:    precision = 1.000    recall = 0.009    F1 = 0.018
# CPU times: user 2.35 s, sys: 6.9 ms, total: 2.36 s
# Wall time: 2.45 s
# /Users/kmike/envs/dl/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 2. Use loginform features, but autodetect scores
#
# The following ML-based model is trained using original loginform features (conditions used to increase or decrease the score). Roughly speaking, it uses the same information as loginform library, but instead of hardcoding `score += 10` and `score -= 10` the numbers are adjusted based on training data.
#
# Note that the login form detection quality is significantly better than the quality of threshold-based model; it is only slightly worse than the quality of a "full" forms detection model. This means original loginform features are quite good at detecting login forms. But for other form types these features are not enough: other scores are bad.

# %%
# %%time

LOGINFORM_FEATURES = [
    ('bias', features.Bias(), DictVectorizer()),
    ('loginform', features.OldLoginformFeatures(), DictVectorizer())
]
# loginform_clf = LinearSVC(C=0.5, fit_intercept=False)
loginform_clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0)

model = make_pipeline(
    _create_feature_union(LOGINFORM_FEATURES), 
    loginform_clf,
)

formtype_model.print_classification_report(annotations, n_folds=10, model=model)

model.fit(X, y)
print_informative_features(LOGINFORM_FEATURES, loginform_clf, 25)
# Out:
#                    precision    recall  f1-score   support
#
#            search       0.55      0.79      0.65       364
#             login       0.92      0.95      0.93       222
#      registration       0.95      0.67      0.78       153
#   contact/comment       0.47      0.73      0.58       120
# join mailing list       0.11      0.01      0.02       107
#             other       0.38      0.59      0.46       122
#
#       avg / total       0.61      0.70      0.64      1088
#
# 61.3% forms are classified correctly.
# contact/comment
# +3.6044:                      loginform  typecount_password_0
# +2.9594:                      loginform  typecount_text_gt1
# +0.1378:                      loginform  typecount_text_0
# +0.0474:                      loginform  typecount_radio_gt0
# -1.3172:                      loginform  typecount_checkbox_gt1
# -1.4733:                      loginform  typecount_password_eq1
# -1.5214:                      loginform  2_or_3_inputs
# -6.5001:                           bias  bias
# --------------------------------------------------------------------------------
# join mailing list
# +2.4583:                      loginform  typecount_password_0
# +1.1901:                      loginform  typecount_checkbox_gt1
# +0.3436:                      loginform  2_or_3_inputs
# -0.2444:                      loginform  typecount_text_0
# -0.7037:                      loginform  typecount_text_gt1
# -0.7194:                      loginform  typecount_radio_gt0
# -1.9839:                      loginform  typecount_password_eq1
# -4.4473:                           bias  bias
# --------------------------------------------------------------------------------
# login
# +5.6971:                      loginform  typecount_password_eq1
# +0.9164:                      loginform  typecount_text_0
# +0.3639:                      loginform  2_or_3_inputs
# -1.8354:                      loginform  typecount_password_0
# -1.9723:                      loginform  typecount_checkbox_gt1
# -2.0403:                      loginform  typecount_radio_gt0
# -2.2831:                      loginform  typecount_text_gt1
# -2.7096:                           bias  bias
# --------------------------------------------------------------------------------
# order/add to cart
# +1.7240:                      loginform  typecount_password_0
# +0.4020:                      loginform  typecount_radio_gt0
# +0.0433:                      loginform  typecount_text_0
# -0.5080:                      loginform  2_or_3_inputs
# -0.8300:                      loginform  typecount_checkbox_gt1
# -1.0047:                      loginform  typecount_text_gt1
# -2.0615:                      loginform  typecount_password_eq1
# -4.0580:                           bias  bias
# --------------------------------------------------------------------------------
# other
# +2.5668:                      loginform  typecount_text_0
# +2.0098:                      loginform  typecount_password_0
# +0.9708:                      loginform  typecount_text_gt1
# +0.8658:                      loginform  typecount_radio_gt0
# +0.0172:                      loginform  typecount_checkbox_gt1
# -0.1391:                      loginform  2_or_3_inputs
# -2.0877:                      loginform  typecount_password_eq1
# -5.0781:                           bias  bias
# --------------------------------------------------------------------------------
# password/login recovery
# +1.2268:                      loginform  typecount_password_0
# +0.7331:                      loginform  2_or_3_inputs
# -0.3935:                      loginform  typecount_text_gt1
# -0.6895:                      loginform  typecount_text_0
# -2.0990:                      loginform  typecount_checkbox_gt1
# -2.3290:                      loginform  typecount_radio_gt0
# -2.7624:                      loginform  typecount_password_eq1
# -3.3845:                           bias  bias
# --------------------------------------------------------------------------------
# registration
# +2.1473:                      loginform  typecount_text_gt1
# +1.5049:                           bias  bias
# +0.6985:                      loginform  typecount_radio_gt0
# +0.6783:                      loginform  typecount_checkbox_gt1
# +0.5736:                      loginform  typecount_text_0
# +0.0624:                      loginform  2_or_3_inputs
# -4.3932:                      loginform  typecount_password_eq1
# -5.9793:                      loginform  typecount_password_0
# --------------------------------------------------------------------------------
# search
# +3.7243:                      loginform  typecount_password_0
# +0.6919:                      loginform  typecount_checkbox_gt1
# -0.0865:                      loginform  2_or_3_inputs
# -0.3891:                      loginform  typecount_radio_gt0
# -1.2802:                      loginform  typecount_text_0
# -2.1901:                      loginform  typecount_text_gt1
# -2.4596:                      loginform  typecount_password_eq1
# -3.4671:                           bias  bias
# --------------------------------------------------------------------------------
# CPU times: user 4.48 s, sys: 5.43 ms, total: 4.49 s
# Wall time: 4.5 s
