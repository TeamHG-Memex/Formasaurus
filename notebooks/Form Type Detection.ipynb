# %%
import sys
sys.path.insert(0, '..')

from formasaurus import formtype_features as features
from formasaurus import evaluation
from formasaurus.storage import Storage, load_html

# %% [markdown]
# ### Available training data

# %%
storage = Storage("../formasaurus/data")
storage.check()
storage.print_form_type_counts(simplify=True)
# Out:
# Checking: 100%|##########################| 696/696 [00:02<00:00, 247.70 files/s]
# Status: OK
# Annotated HTML forms (simplified classes):
#
# 317   search                    (s)
# 198   login                     (l)
# 133   registration              (r)
# 112   other                     (o)
# 109   contact/comment           (c)
# 86    password/login recovery   (p)
# 83    join mailing list         (m)
# 37    order/add to cart         (b)
#
# Total form count: 1075

# %% [markdown]
# ## Load training / evaluation data
#
# We must be careful when splitting the dataset into training and evaluation parts: forms from the same domain should be in the same "bin". There could be several pages from the same domain, and these pages may have duplicate or similar forms (e.g. a search form on each page). If we put one such form in training dataset and another in evaluation dataset then the metrics will be too optimistic, and they can make us to choose wrong features/models. For example, train_test_split from scikit-learn shouldn't be used here.
#
# As an approximation, data is sorted by a domain below (it is done in storage.get_Xy function), and then it is split into 2 parts. It means that no more than 1 domain is prone to overfitting (the one we're splitting at).

# %%
TRAIN_SIZE = 700

X, y = storage.get_Xy(verbose=True, leave=True)
X_train, X_test, y_train, y_test = X[:TRAIN_SIZE], X[TRAIN_SIZE:], y[:TRAIN_SIZE], y[TRAIN_SIZE:]

print("Train size: %d, test size: %d" % (len(y_train), len(y_test)))
# Out:
# Loading: 696 files [00:02, 247.61 files/s]
# Train size: 700, test size: 375

# %% [markdown]
# ## Ideas for useful features
#
# ### Search forms
#
# * a single query field
# * a field named "q" or "s"
# * "search" in URL
# * "search" in submit button text (submit value)
# * "search" in form css class or id
# * no password field
# * method == GET?
#
# ### Login forms
#
# * username or email and password
# * 2 passwords - likely not a login form
# * "login" or "sign in" (or variations) in URL
# * "login" or "sign in" (or variations) in form css class or id
# * "login" or "sign in" in submit button text
# * "Remember me" checkbox (or any single checkbox)
# * no select elements
# * no textarea elements
# * openid?
# * method == POST
#
# ### Registration forms
#
# * 2 passwords
# * "register" / "sign up" in URL, form css class / id or submit button text
# * "agree" checkbox
# * email
# * username
# * method == POST
#
# ### Contact forms
#
# * feedback in URL/class
# * textarea
# * "Send" button
# * email
# * method == POST
#
# ### Password reset
#
# * a single email or username field
# * "password" in URL/css class/ submit button text
#
# ### Join Mailing List
#
# * a single email field
# * subscribe/join/newsletter words
# * a short form
#
# The main problem with "join mailing list" forms is to distinguish them from search forms.
#
# ## How to handle them
#
# Instead of hardcoding the features above many of them are generalized. For exmaple, instead of writing "search in URL" we extract all 5-character substrings from the URL and use "`urlsubstring<N>` in URL" as features. There are some disadvantages in this approach, but it provides a good starting point.
#
# The feature extractors are stored in formtype.features module.

# %%
from scipy import stats as st
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline, make_union
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.grid_search import RandomizedSearchCV
from sklearn.svm import LinearSVC
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support

# %%
# %%time
# reload(features)
from formasaurus.formtype_model import _create_feature_union
# ======= define the model ========

# features should be kept in sync with formasaurus.formtype_model
# a list of 3-tuples with default features:
# (feature_name, form_transformer, vectorizer)
FEATURES = [
    (
        "bias",
        features.Bias(),
        DictVectorizer(),
    ),
    (
        "form elements",
        features.FormElements(),
        DictVectorizer()
    ),
    (
        "<input type=submit value=...>",
        features.SubmitText(),
        CountVectorizer(ngram_range=(1,2), min_df=1, binary=True)
    ),
    (
        "<a> TEXT </a>",
        features.FormLinksText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=4, binary=True,
                        stop_words={'and', 'or', 'of'})
    ),
    (
        "<label> TEXT </label>",
        features.FormLabelText(),
        TfidfVectorizer(ngram_range=(1,2), min_df=3, binary=True,
                        stop_words="english")
    ),

    (
        "<form action=...>",
        features.FormUrl(),
        TfidfVectorizer(ngram_range=(5,6), min_df=4, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<form class=... id=...>",
        features.FormCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input class=... id=...>",
        features.FormInputCss(),
        TfidfVectorizer(ngram_range=(4,5), min_df=5, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input name=...>",
        features.FormInputNames(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
    (
        "<input title=...>",
        features.FormInputTitle(),
        TfidfVectorizer(ngram_range=(5,6), min_df=3, binary=True,
                        analyzer="char_wb")
    ),
]


# clf = SGDClassifier(
#     penalty='elasticnet', 
#     loss='log', 
#     alpha=0.0002,
#     fit_intercept=False, 
#     shuffle=True, 
#     random_state=0,
#     n_iter=50,
# )
clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0, tol=0.01)

# clf = LinearSVC(C=0.5, random_state=0, fit_intercept=False)
model = Pipeline([
    ('fe', _create_feature_union(FEATURES)),
    ('clf', clf),
])

evaluation.print_metrics(model, X, y, X_train, X_test, y_train, y_test, ipython=True)
# Out:
# Classification report (700 training examples, 375 testing examples):
#
#              precision    recall  f1-score   support
#
#           b       0.75      0.43      0.55         7
#           c       0.75      0.94      0.83        32
#           l       0.97      0.90      0.94        73
#           m       0.82      0.88      0.85        32
#           o       0.66      0.62      0.64        47
#           p       0.93      0.81      0.86        31
#           r       0.95      0.87      0.91        47
#           s       0.90      0.98      0.94       106
#
# avg / total       0.87      0.87      0.87       375
#
# Active features: 48968 out of possible 48968
#
# Confusion matrix (rows=>true values, columns=>predicted values):
#    b   c   l   m   o   p   r    s
# b  3   1   0   0   3   0   0    0
# c  0  30   0   0   2   0   0    0
# l  0   0  66   1   6   0   0    0
# m  0   2   0  28   0   0   1    1
# o  1   7   0   0  29   1   0    9
# p  0   0   0   4   0  25   1    1
# r  0   0   2   1   2   1  41    0
# s  0   0   0   0   2   0   0  104
# Running cross validation...
# 10-fold cross-validation F1: 0.886 (±0.058)  min=0.836  max=0.924
# CPU times: user 11.9 s, sys: 67.4 ms, total: 12 s
# Wall time: 12.1 s
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Check what classifier learned
#
# For linear classifiers like Logistic Regression or an SVM without a kernel we can check coefficient values to understand better how the decision is made.
#
# For correlated features weight will be spread across all correlated features, so just checking coefficients is not enough, but looking at them is useful anyways.

# %%
evaluation.print_informative_features(FEATURES, clf, 25)
# Out:
# b
# +2.5555:               <input name=...>   qty
# +1.8767:              <form action=...>   prod
# +1.8762:                  <a> TEXT </a>  email
# +1.2177:               <input name=...>  oncode
# +1.2177:               <input name=...>  oncod
# +1.1715:               <input name=...>  ncode
# +1.1715:               <input name=...>  ncode
# +1.1526:       <input class=... id=...>   qty
# +1.1463:  <input type=submit value=...>  заказ
# +1.1463:  <input type=submit value=...>  оплатить заказ
# +1.1463:  <input type=submit value=...>  оплатить
# +1.1309:                  form elements  has <select>
# +1.0815:              <form action=...>  .asp#
# +1.0815:              <form action=...>  asp#
# +1.0815:              <form action=...>  .asp#
# +1.0750:               <input name=...>  quant
# +1.0679:              <input title=...>   add
# +1.0518:               <input name=...>   order
# +1.0518:               <input name=...>  order
# +1.0518:               <input name=...>   orde
# +1.0479:  <input type=submit value=...>  acquista
# +1.0348:        <form class=... id=...>  ine
# +0.9798:  <input type=submit value=...>  корзину отправить
# +0.9798:  <input type=submit value=...>  корзину
# +0.9401:  <input type=submit value=...>  koupit
#    ...
# -0.5106:              <form action=...>  search
# -0.5106:              <form action=...>  earch
# -0.5106:              <form action=...>  searc
# -0.5624:  <input type=submit value=...>  search
# -0.6146:        <form class=... id=...>  form
# -0.6336:        <form class=... id=...>  orm
# -0.6340:        <form class=... id=...>  form
# -0.6419:               <input name=...>   email
# -0.6419:               <input name=...>   emai
# -0.6662:               <input name=...>  email
# -0.6764:                  form elements  has <input type=checkbox>
# -0.7129:               <input name=...>  email
# -0.7389:               <input name=...>  mail
# -0.7572:                  form elements  has <input type=email>
# -0.8093:  <input type=submit value=...>  submit
# -0.8377:                  form elements  no <input type=text>
# -0.8623:                  form elements  <form method=post
# -0.9180:               <input name=...>   s
# -0.9953:                  form elements  exactly two <input type=password>
# -1.0379:               <input name=...>   q
# -1.0587:                  form elements  2 or 3 inputs
# -1.2363:                  form elements  exactly two <input type=text>
# -1.2986:                  form elements  <form method=get
# -1.3925:                  form elements  exactly one <input type=password>
# -2.1609:                           bias  bias
# --------------------------------------------------------------------------------
# c
# +5.1921:                  form elements  has <textarea>
# +1.7177:                  <a> TEXT </a>  contact
# +1.7148:                  <a> TEXT </a>  contact us
# +1.5758:                  <a> TEXT </a>  forums
# +1.5736:                  <a> TEXT </a>  us
# +1.2971:                  <a> TEXT </a>  privacy
# +1.0313:  <input type=submit value=...>  submit
# +1.0042:  <input type=submit value=...>  send
# +0.8887:          <label> TEXT </label>  comments
# +0.8643:                  form elements  has <input type=email>
# +0.7778:              <form action=...>  conta
# +0.6880:          <label> TEXT </label>  question
# +0.6554:              <form action=...>  ntact
# +0.6554:              <form action=...>  ontact
# +0.6554:              <form action=...>  ontac
# +0.6554:              <form action=...>  contac
# +0.6443:              <form action=...>   send
# +0.6388:          <label> TEXT </label>  policy
# +0.6293:        <form class=... id=...>  back
# +0.5788:          <label> TEXT </label>  message
# +0.5700:          <label> TEXT </label>  phone email
# +0.5430:  <input type=submit value=...>  értesítőt küldök
# +0.5430:  <input type=submit value=...>  küldök
# +0.5430:  <input type=submit value=...>  neki
# +0.5430:  <input type=submit value=...>  küldök neki
#    ...
# -0.5608:        <form class=... id=...>  efor
# -0.5608:        <form class=... id=...>  eform
# -0.5634:               <input name=...>   q
# -0.5826:  <input type=submit value=...>  now
# -0.5852:                  form elements  has <input type=radio>
# -0.5862:        <form class=... id=...>  site
# -0.5877:        <form class=... id=...>  der
# -0.6030:  <input type=submit value=...>  crear
# -0.6090:              <input title=...>   add
# -0.6270:          <label> TEXT </label>  login
# -0.6434:               <input name=...>   mail
# -0.6539:                  form elements  has <select>
# -0.6760:               <input name=...>   mail
# -0.7286:  <input type=submit value=...>  registrovať
# -0.7682:                  <a> TEXT </a>  this
# -0.8491:                  form elements  exactly one <input type=password>
# -0.9004:                  form elements  <form method=get
# -0.9142:  <input type=submit value=...>  корзину
# -0.9142:  <input type=submit value=...>  корзину отправить
# -0.9626:                  form elements  has <input type=checkbox>
# -1.3778:                  form elements  2 or 3 inputs
# -1.4798:                  form elements  <form method=post
# -1.6868:                  form elements  exactly one <input type=text>
# -2.0374:                  form elements  exactly two <input type=password>
# -2.3802:                           bias  bias
# --------------------------------------------------------------------------------
# l
# +3.1417:                  form elements  exactly one <input type=password>
# +1.7054:  <input type=submit value=...>  login
# +1.3546:              <form action=...>  login
# +1.2807:  <input type=submit value=...>  войти
# +1.1154:  <input type=submit value=...>  войти войти
# +1.0395:  <input type=submit value=...>  in
# +0.9817:                  form elements  2 or 3 inputs
# +0.9753:              <form action=...>   logi
# +0.9753:              <form action=...>   login
# +0.8562:  <input type=submit value=...>  sign in
# +0.8444:                  form elements  has <input type=checkbox>
# +0.8284:          <label> TEXT </label>  remember
# +0.7911:                  <a> TEXT </a>  facebook
# +0.7911:                  <a> TEXT </a>  twitter
# +0.7681:          <label> TEXT </label>  url
# +0.7135:               <input name=...>  openi
# +0.7135:               <input name=...>   open
# +0.7135:               <input name=...>   openi
# +0.6216:  <input type=submit value=...>  sign
# +0.5846:        <form class=... id=...>  login
# +0.5846:        <form class=... id=...>  logi
# +0.5846:        <form class=... id=...>  ogin
# +0.5123:              <form action=...>  gin#
# +0.5123:              <form action=...>  ogin#
# +0.5123:              <form action=...>  login#
#    ...
# -0.4078:               <input name=...>   emai
# -0.4136:  <input type=submit value=...>  now
# -0.4248:  <input type=submit value=...>  register now
# -0.4607:                  form elements  has <input type=radio>
# -0.5075:               <input name=...>   q
# -0.5379:                  form elements  has <textarea>
# -0.5414:  <input type=submit value=...>  account
# -0.5435:  <input type=submit value=...>  create
# -0.5452:  <input type=submit value=...>  create account
# -0.5588:               <input name=...>  mail
# -0.5596:               <input name=...>  email
# -0.5709:               <input name=...>  email
# -0.5800:                  <a> TEXT </a>  terms
# -0.5939:                  <a> TEXT </a>  com
# -0.6610:                  form elements  <form method=post
# -0.8083:                  form elements  exactly two <input type=text>
# -0.8738:                  form elements  <form method=get
# -0.9189:  <input type=submit value=...>  register
# -0.9313:  <input type=submit value=...>  зарегистрироваться
# -1.0960:                  form elements  has <input type=email>
# -1.1755:                  form elements  exactly two <input type=password>
# -1.3417:                  form elements  3 or more <input type=text>
# -1.4595:                  form elements  has <select>
# -1.5347:                           bias  bias
# -3.4834:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# m
# +1.8135:  <input type=submit value=...>  subscribe
# +1.7502:  <input type=submit value=...>  подписаться
# +1.4959:               <input name=...>   email
# +1.4959:               <input name=...>   emai
# +1.2879:               <input name=...>  mail
# +1.1884:  <input type=submit value=...>  submit
# +1.1332:  <input type=submit value=...>  me
# +1.1307:        <form class=... id=...>  mail
# +1.0901:               <input name=...>  email
# +1.0826:                  form elements  has <input type=email>
# +1.0349:  <input type=submit value=...>  cadastrar
# +1.0203:               <input name=...>  email
# +0.8937:       <input class=... id=...>  aili
# +0.8937:       <input class=... id=...>  maili
# +0.8655:        <form class=... id=...>  ewsle
# +0.8655:        <form class=... id=...>  wslet
# +0.8655:        <form class=... id=...>  ewsl
# +0.8655:        <form class=... id=...>  news
# +0.8655:        <form class=... id=...>  wsle
# +0.8655:        <form class=... id=...>  ette
# +0.8655:        <form class=... id=...>  lett
# +0.8655:        <form class=... id=...>  lette
# +0.8655:        <form class=... id=...>  newsl
# +0.8655:        <form class=... id=...>  tter
# +0.8655:        <form class=... id=...>  slet
#    ...
# -0.5163:        <form class=... id=...>  pass
# -0.5181:              <form action=...>  ssword
# -0.5181:              <form action=...>  sswor
# -0.5181:              <form action=...>  sword
# -0.5181:              <form action=...>  passwo
# -0.5181:              <form action=...>  passw
# -0.5181:              <form action=...>  asswo
# -0.5181:              <form action=...>  asswor
# -0.5513:          <label> TEXT </label>  mail adresse
# -0.5790:          <label> TEXT </label>  email
# -0.6118:          <label> TEXT </label>  address
# -0.6264:                  form elements  exactly one <input type=text>
# -0.6411:                  form elements  exactly two <input type=text>
# -0.6812:                  form elements  no <input type=text>
# -0.7126:          <label> TEXT </label>  adresse
# -0.8324:          <label> TEXT </label>  password
# -0.8724:               <input name=...>   q
# -0.9182:          <label> TEXT </label>  mail
# -1.0636:                  form elements  exactly two <input type=password>
# -1.0824:                  form elements  <form method=post
# -1.3376:                  form elements  <form method=get
# -1.3398:                  form elements  has <select>
# -1.7210:                  form elements  exactly one <input type=password>
# -1.8546:                  form elements  has <textarea>
# -2.4200:                           bias  bias
# --------------------------------------------------------------------------------
# o
# +1.6950:                  form elements  no <input type=text>
# +1.4204:                  <a> TEXT </a>  conditions
# +1.2141:               <input name=...>  code
# +1.1845:          <label> TEXT </label>  list
# +1.1440:                  form elements  has <input type=radio>
# +1.1204:          <label> TEXT </label>  description
# +1.1185:  <input type=submit value=...>  mentése
# +1.1185:  <input type=submit value=...>  keresés mentése
# +1.0149:              <form action=...>  ers#
# +0.9897:          <label> TEXT </label>  email phone
# +0.9504:              <form action=...>  check
# +0.9484:        <form class=... id=...>  form-
# +0.9484:        <form class=... id=...>  orm-
# +0.9484:  <input type=submit value=...>  статус
# +0.9484:  <input type=submit value=...>  проверить статус
# +0.9484:  <input type=submit value=...>  проверить
# +0.9448:        <form class=... id=...>  jump
# +0.9409:              <form action=...>  ity#
# +0.9377:               <input name=...>  filte
# +0.9377:               <input name=...>  ilter
# +0.9377:               <input name=...>  filter
# +0.9265:  <input type=submit value=...>  keresés
# +0.8834:              <form action=...>   cont
# +0.8722:  <input type=submit value=...>  вперёд
# +0.8492:        <form class=... id=...>  orm-s
#    ...
# -0.6985:               <input name=...>  submi
# -0.7009:       <input class=... id=...>  arch
# -0.7055:               <input name=...>  email
# -0.7341:               <input name=...>  email
# -0.7802:              <form action=...>  &sid=
# -0.7837:                  form elements  has <input type=checkbox>
# -0.8019:  <input type=submit value=...>  search
# -0.8161:                  form elements  <form method=post
# -0.8710:               <input name=...>   qty
# -0.8796:          <label> TEXT </label>  search
# -0.8898:          <label> TEXT </label>  mail
# -0.9048:               <input name=...>  mail
# -1.0168:                  <a> TEXT </a>  contact
# -1.0215:                  <a> TEXT </a>  privacy
# -1.0226:                  <a> TEXT </a>  contact us
# -1.1062:          <label> TEXT </label>  year
# -1.1137:               <input name=...>   s
# -1.1477:                           bias  bias
# -1.2553:                  <a> TEXT </a>  forums
# -1.2784:                  form elements  exactly two <input type=text>
# -1.3050:                  form elements  exactly one <input type=password>
# -1.4381:                  form elements  has <input type=email>
# -1.5826:                  form elements  exactly one <input type=text>
# -1.5983:               <input name=...>   q
# -1.9031:                  form elements  has <textarea>
# --------------------------------------------------------------------------------
# p
# +1.3622:  <input type=submit value=...>  priminti
# +1.3043:  <input type=submit value=...>  odošli
# +1.3035:        <form class=... id=...>  pass
# +1.2613:               <input name=...>  mail
# +1.2202:  <input type=submit value=...>  reset
# +1.2137:  <input type=submit value=...>  go
# +1.1357:                  form elements  2 or 3 inputs
# +1.0630:          <label> TEXT </label>  mail
# +1.0548:  <input type=submit value=...>  password
# +1.0009:  <input type=submit value=...>  absenden
# +0.9612:              <form action=...>  asswo
# +0.9612:              <form action=...>  sswor
# +0.9612:              <form action=...>  ssword
# +0.9612:              <form action=...>  sword
# +0.9612:              <form action=...>  passwo
# +0.9612:              <form action=...>  passw
# +0.9612:              <form action=...>  asswor
# +0.9515:  <input type=submit value=...>  次へ
# +0.9405:  <input type=submit value=...>  enviar
# +0.9057:               <input name=...>  email
# +0.8874:               <input name=...>  login
# +0.8874:               <input name=...>  ogin
# +0.8694:          <label> TEXT </label>  email
# +0.8562:               <input name=...>   user
# +0.8319:        <form class=... id=...>  orgo
#    ...
# -0.3915:  <input type=submit value=...>  me
# -0.4057:               <input name=...>  code
# -0.4084:       <input class=... id=...>  sear
# -0.4810:                  <a> TEXT </a>  email
# -0.5110:               <input name=...>   qty
# -0.5173:                  form elements  exactly one <input type=text>
# -0.5189:  <input type=submit value=...>  search
# -0.5475:              <form action=...>  signup
# -0.5475:              <form action=...>  signu
# -0.5475:              <form action=...>  ignup
# -0.5586:              <form action=...>   signu
# -0.5586:              <form action=...>   sign
# -0.7481:  <input type=submit value=...>  подписаться
# -0.9097:                  form elements  3 or more <input type=text>
# -0.9200:               <input name=...>   q
# -1.0180:                  form elements  exactly two <input type=password>
# -1.0776:                  form elements  has <input type=radio>
# -1.2396:                  form elements  no <input type=text>
# -1.2509:  <input type=submit value=...>  subscribe
# -1.3834:                  form elements  has <input type=checkbox>
# -1.6648:                  form elements  has <select>
# -1.8419:                  form elements  has <textarea>
# -2.2909:                  form elements  exactly one <input type=password>
# -2.4166:                  form elements  <form method=get
# -2.7709:                           bias  bias
# --------------------------------------------------------------------------------
# r
# +2.6961:                  form elements  exactly two <input type=password>
# +1.2601:  <input type=submit value=...>  register
# +1.2363:  <input type=submit value=...>  create
# +1.2162:  <input type=submit value=...>  registrovať
# +1.1603:                  form elements  3 or more <input type=text>
# +1.1367:              <form action=...>  ster#
# +1.1367:              <form action=...>  ster#
# +1.1367:              <form action=...>  ister#
# +1.1066:               <input name=...>  emailc
# +1.1066:               <input name=...>  mailc
# +1.0877:              <form action=...>  regis
# +1.0877:              <form action=...>  egist
# +1.0877:              <form action=...>  regist
# +1.0748:  <input type=submit value=...>  免费注册
# +1.0584:              <form action=...>  ister
# +1.0584:              <form action=...>  gister
# +1.0584:              <form action=...>  giste
# +1.0584:              <form action=...>  egiste
# +1.0545:              <form action=...>  ter#
# +1.0334:  <input type=submit value=...>  зарегистрироваться
# +1.0091:  <input type=submit value=...>  avançar
# +0.9131:                  <a> TEXT </a>  com
# +0.9050:  <input type=submit value=...>  proceed
# +0.8631:       <input class=... id=...>  s_re
# +0.8259:                  <a> TEXT </a>  www
#    ...
# -0.4835:               <input name=...>  otion
# -0.4835:               <input name=...>  motion
# -0.4835:               <input name=...>  motio
# -0.4897:                  <a> TEXT </a>  forgot
# -0.5038:              <form action=...>   logi
# -0.5038:              <form action=...>   login
# -0.5079:  <input type=submit value=...>  in
# -0.5206:                  <a> TEXT </a>  password
# -0.5238:              <form action=...>  ogin#
# -0.5238:              <form action=...>  ogin#
# -0.5238:              <form action=...>  login#
# -0.5238:              <form action=...>  gin#
# -0.5345:                  <a> TEXT </a>  conditions
# -0.5985:                  <a> TEXT </a>  the
# -0.6162:                  form elements  has <input type=checkbox>
# -0.8690:              <form action=...>  login
# -0.9768:                           bias  bias
# -1.0121:  <input type=submit value=...>  login
# -1.0277:                  form elements  2 or 3 inputs
# -1.0420:                  form elements  exactly one <input type=password>
# -1.1636:                  form elements  <form method=get
# -1.3043:                  form elements  has <textarea>
# -1.3461:                  form elements  exactly one <input type=text>
# -1.4723:                  form elements  no <input type=text>
# -2.6795:                  form elements  no <input type=password>
# --------------------------------------------------------------------------------
# s
# +2.6448:               <input name=...>   q
# +2.2049:               <input name=...>   s
# +1.7464:          <label> TEXT </label>  year
# +1.6309:              <form action=...>  &sid=
# +1.5202:  <input type=submit value=...>  search
# +1.2459:              <form action=...>   page
# +1.2370:                  form elements  has <select>
# +1.1949:               <input name=...>  earch
# +1.1949:               <input name=...>  searc
# +1.1949:               <input name=...>  search
# +1.1741:               <input name=...>  text
# +1.1728:       <input class=... id=...>  earc
# +1.1728:       <input class=... id=...>  earch
# +1.1728:       <input class=... id=...>  searc
# +1.1677:       <input class=... id=...>  arch
# +1.1433:       <input class=... id=...>  sear
# +1.1352:        <form class=... id=...>  efor
# +1.1352:        <form class=... id=...>  eform
# +1.0738:              <form action=...>  page=
# +1.0683:               <input name=...>   searc
# +1.0683:               <input name=...>   sear
# +1.0073:        <form class=... id=...>  arch
# +1.0073:        <form class=... id=...>  earc
# +1.0073:        <form class=... id=...>  earch
# +1.0073:        <form class=... id=...>  sear
#    ...
# -0.6387:        <form class=... id=...>  lect
# -0.6387:        <form class=... id=...>  er_se
# -0.6387:        <form class=... id=...>  _sele
# -0.6430:        <form class=... id=...>  er_s
# -0.6489:               <input name=...>  name
# -0.6525:        <form class=... id=...>  ter_s
# -0.6962:        <form class=... id=...>  jump
# -0.7524:  <input type=submit value=...>  login
# -0.7532:               <input name=...>  code
# -0.7725:                  form elements  has <input type=email>
# -0.7823:          <label> TEXT </label>  email
# -0.7925:                  <a> TEXT </a>  email
# -1.0313:  <input type=submit value=...>  submit
# -1.0494:                  form elements  no <input type=text>
# -1.1873:               <input name=...>  email
# -1.2604:                  form elements  3 or more <input type=text>
# -1.2863:               <input name=...>   email
# -1.2863:               <input name=...>   emai
# -1.2878:               <input name=...>   qty
# -1.3115:               <input name=...>  mail
# -1.3324:               <input name=...>  email
# -1.5461:                  form elements  <form method=post
# -1.5965:                           bias  bias
# -1.7742:                  form elements  has <textarea>
# -2.0376:                  form elements  exactly one <input type=password>
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Compare results with "loginform" library
#
# It is not possible to compare the results with "loginform" library directly because loginform
#
# * always tries to return a login form even if the score is low;
# * only detects login forms;
# * in case of several forms returns a single form with the best score instead of deciding for each form whether to return it or not.
#
# So we used two approaches:
#
# 1. Use `loginform._form_score` with different thresholds; assume that if score is greater than or equal to a threshold `loginform` detected a login form.
# 2. Train the same model, but using features from loginform library (weights will be learned instead of being hardcoded as 'score' increments/decrements).

# %% [markdown]
# ### 1. loginform scores + thresholds
#
# * **score >= -100** means "simply treat all forms as login forms".
#
# * **score >= 0** all (or most) login forms are captured, but there are many false positives.
#   It is only slightly better than treating all forms as login forms.
#
# * **score >= 10** F1 score is the best among all thresholds,
#   but the quality is significantly worse than F1 of ML-based models.
#
# * **score >= 20** ~90% of detected login forms are correct, but most
#   login forms are not detected. Also, ~90% number is still lower than what ML-based models give us.

# %%
# %%time 
import loginform


def labels_to_binary(y):
    """ Convert labels to 2-classes: login forms and non-login forms """
    return [tp == 'l' for tp in y]

    
def predict_loginform(X, threshold):
    """
    Return if forms are login or not using loginform
    library scores and a threshold.
    """
    return [
        (loginform._form_score(form) >= threshold)
        for form in X
    ]


def print_threshold_metrics(X_test, y_test, threshold):
    y_test = labels_to_binary(y_test)
    y_pred = predict_loginform(X_test, threshold)

    precision, recall, f1, support = precision_recall_fscore_support(y_test, y_pred, pos_label=True)
    print(
        "score >= %4d:    precision = %0.3f    recall = %0.3f    F1 = %0.3f" % (
        threshold, precision[1], recall[1], f1[1]
    ))


for threshold in [-100, -10, 0, 10, 20, 30]:
    print_threshold_metrics(X_test, y_test, threshold)
# Out:
# score >= -100:    precision = 0.195    recall = 1.000    F1 = 0.326
# score >=  -10:    precision = 0.213    recall = 0.918    F1 = 0.346
# score >=    0:    precision = 0.330    recall = 0.918    F1 = 0.486
# score >=   10:    precision = 0.675    recall = 0.767    F1 = 0.718
# score >=   20:    precision = 0.840    recall = 0.288    F1 = 0.429
# score >=   30:    precision = 1.000    recall = 0.014    F1 = 0.027
# CPU times: user 667 ms, sys: 4.26 ms, total: 671 ms
# Wall time: 674 ms
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### 2. Use loginform features, but autodetect scores
#
# The following ML-based model is trained using original loginform features (conditions used to increase or decrease the score). Roughly speaking, it uses the same information as loginform library, but instead of hardcoding `score += 10` and `score -= 10` the numbers are adjusted based on training data.
#
# Note that the login form detection quality is significantly better than the quality of threshold-based model; it is only slightly worse than the quality of a "full" forms detection model. This means original loginform features are quite good at detecting login forms. But for other form types these features are not enough: other scores are bad.

# %%
# %%time

LOGINFORM_FEATURES = [
    ('bias', features.Bias(), DictVectorizer()),
    ('loginform', features.OldLoginformFeatures(), DictVectorizer())
]
# loginform_clf = LinearSVC(C=0.5, fit_intercept=False)
loginform_clf = LogisticRegression(penalty='l2', C=5, fit_intercept=False, random_state=0)

model = make_pipeline(
    _create_feature_union(LOGINFORM_FEATURES), 
    loginform_clf,
)

evaluation.print_metrics(model, X, y, X_train, X_test, y_train, y_test, ipython=True)
evaluation.print_informative_features(LOGINFORM_FEATURES, loginform_clf, 25)
# Out:
# Classification report (700 training examples, 375 testing examples):
#
#              precision    recall  f1-score   support
#
#           b       0.00      0.00      0.00         7
#           c       0.43      0.81      0.57        32
#           l       0.92      0.89      0.90        73
#           m       0.00      0.00      0.00        32
#           o       0.43      0.62      0.51        47
#           p       0.00      0.00      0.00        31
#           r       0.94      0.70      0.80        47
#           s       0.57      0.76      0.65       106
#
# avg / total       0.55      0.62      0.57       375
#
# Active features: 64 out of possible 64
#
# Confusion matrix (rows=>true values, columns=>predicted values):
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#    b   c   l  m   o  p   r   s
# b  0   1   0  0   4  0   0   2
# c  0  26   0  0   2  0   1   3
# l  0   1  65  0   6  0   0   1
# m  0   4   0  0   3  0   0  25
# o  0  12   0  0  29  0   0   6
# p  0   2   0  0   5  0   1  23
# r  0   4   6  0   3  0  33   1
# s  0  10   0  0  15  0   0  81
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/kmike/envs/py3-splash/lib/python3.4/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Running cross validation...
# 10-fold cross-validation F1: 0.573 (±0.100)  min=0.502  max=0.645
# b
# +1.3924:                      loginform  typecount_password_0
# +0.5631:                      loginform  typecount_radio_gt0
# -0.6217:                      loginform  typecount_text_gt1
# -0.6524:                      loginform  2_or_3_inputs
# -0.7379:                      loginform  typecount_checkbox_gt1
# -0.8396:                      loginform  typecount_text_0
# -1.8808:                      loginform  typecount_password_eq1
# -3.7685:                           bias  bias
# --------------------------------------------------------------------------------
# c
# +3.2011:                      loginform  typecount_password_0
# +2.8215:                      loginform  typecount_text_gt1
# +0.0203:                      loginform  typecount_text_0
# -0.3697:                      loginform  typecount_radio_gt0
# -1.2807:                      loginform  typecount_checkbox_gt1
# -1.5019:                      loginform  typecount_password_eq1
# -1.7555:                      loginform  2_or_3_inputs
# -5.7343:                           bias  bias
# --------------------------------------------------------------------------------
# l
# +5.0164:                      loginform  typecount_password_eq1
# +1.0720:                      loginform  2_or_3_inputs
# -0.8578:                      loginform  typecount_text_0
# -2.1925:                           bias  bias
# -2.2093:                      loginform  typecount_text_gt1
# -2.2589:                      loginform  typecount_radio_gt0
# -2.5071:                      loginform  typecount_checkbox_gt1
# -2.8641:                      loginform  typecount_password_0
# --------------------------------------------------------------------------------
# m
# +1.8357:                      loginform  typecount_password_0
# +1.3940:                      loginform  typecount_checkbox_gt1
# +0.3792:                      loginform  2_or_3_inputs
# +0.2621:                      loginform  typecount_text_0
# -0.4678:                      loginform  typecount_text_gt1
# -1.1941:                      loginform  typecount_radio_gt0
# -1.8561:                      loginform  typecount_password_eq1
# -4.2015:                           bias  bias
# --------------------------------------------------------------------------------
# o
# +2.8231:                      loginform  typecount_text_0
# +1.1693:                      loginform  typecount_password_0
# +1.0367:                      loginform  typecount_radio_gt0
# +0.5986:                      loginform  typecount_text_gt1
# +0.2006:                      loginform  typecount_checkbox_gt1
# -0.1854:                      loginform  2_or_3_inputs
# -2.2599:                      loginform  typecount_password_eq1
# -4.3036:                           bias  bias
# --------------------------------------------------------------------------------
# p
# +1.4116:                      loginform  typecount_password_0
# +0.9634:                      loginform  2_or_3_inputs
# -0.3574:                      loginform  typecount_text_gt1
# -0.7747:                      loginform  typecount_text_0
# -1.8291:                      loginform  typecount_checkbox_gt1
# -1.8640:                      loginform  typecount_radio_gt0
# -2.2721:                      loginform  typecount_password_eq1
# -3.6461:                           bias  bias
# --------------------------------------------------------------------------------
# r
# +2.0624:                      loginform  typecount_text_gt1
# +1.0741:                           bias  bias
# +0.7804:                      loginform  typecount_checkbox_gt1
# +0.6134:                      loginform  typecount_text_0
# +0.6129:                      loginform  typecount_radio_gt0
# -0.1481:                      loginform  2_or_3_inputs
# -3.7412:                      loginform  typecount_password_eq1
# -5.2834:                      loginform  typecount_password_0
# --------------------------------------------------------------------------------
# s
# +3.1869:                      loginform  typecount_password_0
# +0.3808:                      loginform  typecount_checkbox_gt1
# -0.0852:                      loginform  typecount_radio_gt0
# -0.1047:                      loginform  2_or_3_inputs
# -1.3515:                      loginform  typecount_text_0
# -2.5160:                      loginform  typecount_password_eq1
# -2.5827:                      loginform  typecount_text_gt1
# -2.8264:                           bias  bias
# --------------------------------------------------------------------------------
# CPU times: user 3.83 s, sys: 7.6 ms, total: 3.83 s
# Wall time: 3.86 s
